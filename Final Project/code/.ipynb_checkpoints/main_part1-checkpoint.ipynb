# %% [markdown]
# # Main For Part 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
from matplotlib import pyplot as plt
# Needed for training
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import random_split, DataLoader
from torch.utils.data.dataset import Subset
# Models
from models_part1 import FinalClassifier , MNISTAutoencoder, CIFAR10Autoencoder
from models_testing import  plot_accuracies,plot_losses,test_classifier,test_classifyingAutoEncoder
from models_testing import create_model_folders,PretrainedModel,save_pretrained_model
# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
base_path = 'trained_models/part_1/'

# %% [markdown]
# # MNIST

# %% [markdown]
# # Preparing Data

# %%
mnist_path = "./mnist_data"

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

train_dataset = torchvision.datasets.MNIST(
    root=mnist_path,  
    train=True,       
    transform=transform,  # Apply transformations here
    download=True     
)

test_dataset = torchvision.datasets.MNIST(
    root=mnist_path,
    train=False,  
    transform=transform,  # Apply same transformations for test data
    download=True
)

print("MNIST dataset downloaded successfully!")
# Out:
# MNIST dataset downloaded successfully!

# %%
train_size = 50_000
val_size = 10_000

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

print(f"Train size: {len(train_dataset)}, Validation size: {len(val_dataset)}, Test size: {len(test_dataset)}")


batch_size = 64

# Create DataLoaders
mnist_train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
mnist_val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
mnist_test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print("DataLoaders created successfully!")

images, labels = next(iter(mnist_train_loader))
print(f"Batch shape: {images.shape}, Labels: {labels[:5]}")
# Out:
# Train size: 50000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!
# Batch shape: torch.Size([64, 1, 28, 28]), Labels: tensor([1, 6, 6, 0, 8])

# %% [markdown]
# # Experiment

# %%
# Model initialization
model = MNISTAutoencoder(latent_dim=128).to(device)

train_losses,val_losses = model.train_autoencoder(train_loader= mnist_train_loader,
                       val_loader=mnist_val_loader,
                       num_epochs=40,
                       learning_rate=1e-3,
                       weight_decay= 1e-3)
# Out:
# Epoch [1/40], Time: 19.49s, Train Loss: 0.0989, Val Loss: 0.0362, LR: 0.0010000
# Epoch [2/40], Time: 10.74s, Train Loss: 0.0432, Val Loss: 0.0313, LR: 0.0010000
# Epoch [3/40], Time: 11.24s, Train Loss: 0.0398, Val Loss: 0.0291, LR: 0.0010000
# Epoch [4/40], Time: 10.78s, Train Loss: 0.0381, Val Loss: 0.0280, LR: 0.0010000
# Epoch [5/40], Time: 10.28s, Train Loss: 0.0371, Val Loss: 0.0271, LR: 0.0010000
# Epoch [6/40], Time: 9.98s, Train Loss: 0.0362, Val Loss: 0.0261, LR: 0.0010000
# Epoch [7/40], Time: 10.42s, Train Loss: 0.0354, Val Loss: 0.0256, LR: 0.0010000
# Epoch [8/40], Time: 10.12s, Train Loss: 0.0348, Val Loss: 0.0249, LR: 0.0010000
# Epoch [9/40], Time: 10.25s, Train Loss: 0.0343, Val Loss: 0.0246, LR: 0.0010000
# Epoch [10/40], Time: 10.82s, Train Loss: 0.0339, Val Loss: 0.0241, LR: 0.0010000
# Epoch [11/40], Time: 10.24s, Train Loss: 0.0335, Val Loss: 0.0242, LR: 0.0010000
# Epoch [12/40], Time: 10.08s, Train Loss: 0.0331, Val Loss: 0.0238, LR: 0.0010000
# Epoch [13/40], Time: 10.31s, Train Loss: 0.0328, Val Loss: 0.0233, LR: 0.0010000
# Epoch [14/40], Time: 10.76s, Train Loss: 0.0325, Val Loss: 0.0229, LR: 0.0010000
# Epoch [15/40], Time: 10.25s, Train Loss: 0.0322, Val Loss: 0.0225, LR: 0.0010000
# Epoch [16/40], Time: 10.42s, Train Loss: 0.0319, Val Loss: 0.0223, LR: 0.0010000
# Epoch [17/40], Time: 10.62s, Train Loss: 0.0317, Val Loss: 0.0220, LR: 0.0010000
# Epoch [18/40], Time: 10.41s, Train Loss: 0.0314, Val Loss: 0.0219, LR: 0.0010000
# Epoch [19/40], Time: 10.52s, Train Loss: 0.0313, Val Loss: 0.0216, LR: 0.0010000
# Epoch [20/40], Time: 11.20s, Train Loss: 0.0311, Val Loss: 0.0217, LR: 0.0010000
# Epoch [21/40], Time: 13.75s, Train Loss: 0.0309, Val Loss: 0.0214, LR: 0.0010000
# Epoch [22/40], Time: 12.78s, Train Loss: 0.0308, Val Loss: 0.0213, LR: 0.0010000
# Epoch [23/40], Time: 11.02s, Train Loss: 0.0307, Val Loss: 0.0216, LR: 0.0010000
# Epoch [24/40], Time: 10.97s, Train Loss: 0.0305, Val Loss: 0.0210, LR: 0.0010000
# Epoch [25/40], Time: 10.95s, Train Loss: 0.0304, Val Loss: 0.0210, LR: 0.0010000
# Epoch [26/40], Time: 11.05s, Train Loss: 0.0303, Val Loss: 0.0211, LR: 0.0010000
# Epoch [27/40], Time: 10.91s, Train Loss: 0.0302, Val Loss: 0.0209, LR: 0.0010000
# Epoch [28/40], Time: 11.05s, Train Loss: 0.0301, Val Loss: 0.0209, LR: 0.0010000
# Epoch [29/40], Time: 10.62s, Train Loss: 0.0300, Val Loss: 0.0205, LR: 0.0010000
# Epoch [30/40], Time: 10.69s, Train Loss: 0.0299, Val Loss: 0.0206, LR: 0.0010000
# Epoch [31/40], Time: 10.68s, Train Loss: 0.0298, Val Loss: 0.0206, LR: 0.0010000
# Epoch [32/40], Time: 10.73s, Train Loss: 0.0297, Val Loss: 0.0205, LR: 0.0010000
# Epoch [33/40], Time: 10.79s, Train Loss: 0.0297, Val Loss: 0.0202, LR: 0.0010000
# Epoch [34/40], Time: 10.75s, Train Loss: 0.0296, Val Loss: 0.0206, LR: 0.0010000
# Epoch [35/40], Time: 10.92s, Train Loss: 0.0296, Val Loss: 0.0204, LR: 0.0010000
# Epoch [36/40], Time: 11.08s, Train Loss: 0.0295, Val Loss: 0.0202, LR: 0.0010000
# Epoch [37/40], Time: 11.16s, Train Loss: 0.0295, Val Loss: 0.0203, LR: 0.0010000
# Epoch [38/40], Time: 11.01s, Train Loss: 0.0294, Val Loss: 0.0201, LR: 0.0010000
# Epoch [39/40], Time: 10.99s, Train Loss: 0.0294, Val Loss: 0.0202, LR: 0.0010000
# Epoch [40/40], Time: 10.46s, Train Loss: 0.0293, Val Loss: 0.0201, LR: 0.0010000

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
pretrained_encoder = model.encoder
for param in pretrained_encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  mnist_train_loader,
                                                                           val_loader = mnist_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-3)
# Out:
# Epoch [1/30], Time: 13.08s, Train Loss: 0.2859, Train Accuracy: 91.50%, Val Accuracy: 96.50%, LR: 0.001000
# Epoch [2/30], Time: 12.65s, Train Loss: 0.1301, Train Accuracy: 96.05%, Val Accuracy: 97.08%, LR: 0.001000
# Epoch [3/30], Time: 12.74s, Train Loss: 0.0926, Train Accuracy: 97.09%, Val Accuracy: 97.67%, LR: 0.001000
# Epoch [4/30], Time: 12.37s, Train Loss: 0.0768, Train Accuracy: 97.51%, Val Accuracy: 97.52%, LR: 0.001000
# Epoch [5/30], Time: 13.31s, Train Loss: 0.0681, Train Accuracy: 97.76%, Val Accuracy: 97.85%, LR: 0.001000
# Epoch [6/30], Time: 13.29s, Train Loss: 0.0568, Train Accuracy: 98.12%, Val Accuracy: 97.77%, LR: 0.001000
# Epoch [7/30], Time: 13.28s, Train Loss: 0.0512, Train Accuracy: 98.31%, Val Accuracy: 97.80%, LR: 0.001000
# Epoch [8/30], Time: 12.20s, Train Loss: 0.0447, Train Accuracy: 98.51%, Val Accuracy: 97.91%, LR: 0.001000
# Epoch [9/30], Time: 12.22s, Train Loss: 0.0438, Train Accuracy: 98.53%, Val Accuracy: 97.94%, LR: 0.001000
# Epoch [10/30], Time: 12.18s, Train Loss: 0.0401, Train Accuracy: 98.63%, Val Accuracy: 97.98%, LR: 0.000125
# Epoch [11/30], Time: 12.19s, Train Loss: 0.0272, Train Accuracy: 99.10%, Val Accuracy: 98.43%, LR: 0.000125
# Epoch [12/30], Time: 12.11s, Train Loss: 0.0209, Train Accuracy: 99.31%, Val Accuracy: 98.31%, LR: 0.000125
# Epoch [13/30], Time: 12.11s, Train Loss: 0.0182, Train Accuracy: 99.44%, Val Accuracy: 98.34%, LR: 0.000125
# Epoch [14/30], Time: 12.34s, Train Loss: 0.0152, Train Accuracy: 99.51%, Val Accuracy: 98.37%, LR: 0.000125
# Epoch [15/30], Time: 12.06s, Train Loss: 0.0161, Train Accuracy: 99.48%, Val Accuracy: 98.53%, LR: 0.000125
# Epoch [16/30], Time: 12.14s, Train Loss: 0.0135, Train Accuracy: 99.55%, Val Accuracy: 98.44%, LR: 0.000125
# Epoch [17/30], Time: 12.06s, Train Loss: 0.0127, Train Accuracy: 99.58%, Val Accuracy: 98.47%, LR: 0.000125
# Epoch [18/30], Time: 12.20s, Train Loss: 0.0117, Train Accuracy: 99.63%, Val Accuracy: 98.56%, LR: 0.000125
# Epoch [19/30], Time: 12.05s, Train Loss: 0.0116, Train Accuracy: 99.62%, Val Accuracy: 98.55%, LR: 0.000125
# Epoch [20/30], Time: 12.17s, Train Loss: 0.0107, Train Accuracy: 99.66%, Val Accuracy: 98.54%, LR: 0.000016
# Epoch [21/30], Time: 12.22s, Train Loss: 0.0094, Train Accuracy: 99.71%, Val Accuracy: 98.51%, LR: 0.000016
# Epoch [22/30], Time: 12.18s, Train Loss: 0.0091, Train Accuracy: 99.72%, Val Accuracy: 98.52%, LR: 0.000016
# Epoch [23/30], Time: 12.05s, Train Loss: 0.0090, Train Accuracy: 99.70%, Val Accuracy: 98.53%, LR: 0.000016
# Epoch [24/30], Time: 12.08s, Train Loss: 0.0086, Train Accuracy: 99.76%, Val Accuracy: 98.50%, LR: 0.000016
# Epoch [25/30], Time: 12.28s, Train Loss: 0.0084, Train Accuracy: 99.73%, Val Accuracy: 98.51%, LR: 0.000016
# Epoch [26/30], Time: 12.10s, Train Loss: 0.0089, Train Accuracy: 99.71%, Val Accuracy: 98.55%, LR: 0.000016
# Epoch [27/30], Time: 12.65s, Train Loss: 0.0078, Train Accuracy: 99.75%, Val Accuracy: 98.52%, LR: 0.000016
# Epoch [28/30], Time: 13.14s, Train Loss: 0.0092, Train Accuracy: 99.67%, Val Accuracy: 98.55%, LR: 0.000016
# Epoch [29/30], Time: 13.32s, Train Loss: 0.0084, Train Accuracy: 99.72%, Val Accuracy: 98.56%, LR: 0.000016
# Epoch [30/30], Time: 12.55s, Train Loss: 0.0086, Train Accuracy: 99.73%, Val Accuracy: 98.54%, LR: 0.000002

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=mnist_test_loader)
# Out:
# Test Accuracy: 98.55%

# %% [markdown]
# ## Save model

# %%
save_pretrained_model(path = base_path + 'mnist.pth',
                      encoder = model.encoder,
                      classifier = classifier,
                      decoder = model.decoder)

# %% [markdown]
# # Cifar10

# %% [markdown]
# # Preparing data

# %%
cifar10_path = "./cifar10_data"

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5,0.5,0.5], std=[0.5,0.5,0.5])
])

c10_full_train_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,  
    train=True,       
    transform=transform,
    download=True     
)

c10_test_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,
    train=False,  
    transform=transform,
    download=True
)

print("CIFAR-10 dataset downloaded successfully!")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CIFAR-10 dataset downloaded successfully!

# %%
train_size = 40_000
val_size = 10_000

c10_train_dataset, c10_val_dataset = random_split(c10_full_train_dataset, [train_size, val_size])

# Check dataset sizes
print(f"Train size: {len(c10_train_dataset)}, Validation size: {len(c10_val_dataset)}, Test size: {len(c10_test_dataset)}")

# Define batch size
batch_size = 64

# Create DataLoaders
c10_train_loader = DataLoader(c10_train_dataset, batch_size=batch_size, shuffle=True)
c10_val_loader = DataLoader(c10_val_dataset, batch_size=batch_size, shuffle=False)
c10_test_loader = DataLoader(c10_test_dataset, batch_size=batch_size, shuffle=False)

print("DataLoaders created successfully!")

# Get a batch of images and labels from the train_loader
images, labels = next(iter(c10_train_loader))
print(f"Batch shape: {images.shape}, Labels (first 5): {labels[:5]}")
# Out:
# Train size: 40000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!
# Batch shape: torch.Size([64, 3, 32, 32]), Labels (first 5): tensor([1, 3, 6, 9, 5])

# %% [markdown]
# # Experiment

# %%
model = CIFAR10Autoencoder(latent_dim=128).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader = c10_train_loader,
                        val_loader = c10_val_loader,
                        num_epochs=40,
                        learning_rate= 1e-3,
                        weight_decay= 1e-3)
# Out:
# Initializing weights ....
# Initializing weights DONE
# Epoch [1/40], Time: 22.19s, Train Loss: 0.1767, Val Loss: 0.1382, LR: 0.0010000
# Epoch [2/40], Time: 12.99s, Train Loss: 0.1311, Val Loss: 0.1190, LR: 0.0010000
# Epoch [3/40], Time: 12.51s, Train Loss: 0.1192, Val Loss: 0.1100, LR: 0.0010000
# Epoch [4/40], Time: 11.94s, Train Loss: 0.1124, Val Loss: 0.1070, LR: 0.0010000
# Epoch [5/40], Time: 12.98s, Train Loss: 0.1079, Val Loss: 0.1023, LR: 0.0010000
# Epoch [6/40], Time: 12.52s, Train Loss: 0.1055, Val Loss: 0.1017, LR: 0.0010000
# Epoch [7/40], Time: 11.80s, Train Loss: 0.1031, Val Loss: 0.0996, LR: 0.0010000
# Epoch [8/40], Time: 11.97s, Train Loss: 0.1016, Val Loss: 0.0981, LR: 0.0010000
# Epoch [9/40], Time: 11.88s, Train Loss: 0.1011, Val Loss: 0.0977, LR: 0.0010000
# Epoch [10/40], Time: 12.89s, Train Loss: 0.0998, Val Loss: 0.0964, LR: 0.0010000
# Epoch [11/40], Time: 14.56s, Train Loss: 0.0994, Val Loss: 0.0977, LR: 0.0010000
# Epoch [12/40], Time: 12.56s, Train Loss: 0.0988, Val Loss: 0.0962, LR: 0.0010000
# Epoch [13/40], Time: 12.10s, Train Loss: 0.0981, Val Loss: 0.0961, LR: 0.0010000
# Epoch [14/40], Time: 12.08s, Train Loss: 0.0978, Val Loss: 0.0951, LR: 0.0010000
# Epoch [15/40], Time: 12.06s, Train Loss: 0.0974, Val Loss: 0.0947, LR: 0.0010000
# Epoch [16/40], Time: 12.64s, Train Loss: 0.0966, Val Loss: 0.0962, LR: 0.0010000
# Epoch [17/40], Time: 12.15s, Train Loss: 0.0966, Val Loss: 0.0951, LR: 0.0010000
# Epoch [18/40], Time: 12.06s, Train Loss: 0.0962, Val Loss: 0.0949, LR: 0.0010000
# Epoch [19/40], Time: 11.85s, Train Loss: 0.0961, Val Loss: 0.0941, LR: 0.0010000
# Epoch [20/40], Time: 12.01s, Train Loss: 0.0958, Val Loss: 0.0948, LR: 0.0010000
# Epoch [21/40], Time: 12.18s, Train Loss: 0.0953, Val Loss: 0.0938, LR: 0.0010000
# Epoch [22/40], Time: 12.08s, Train Loss: 0.0951, Val Loss: 0.0947, LR: 0.0010000
# Epoch [23/40], Time: 11.96s, Train Loss: 0.0950, Val Loss: 0.0936, LR: 0.0010000
# Epoch [24/40], Time: 11.98s, Train Loss: 0.0947, Val Loss: 0.0939, LR: 0.0010000
# Epoch [25/40], Time: 12.35s, Train Loss: 0.0945, Val Loss: 0.0939, LR: 0.0010000
# Epoch [26/40], Time: 12.44s, Train Loss: 0.0944, Val Loss: 0.0927, LR: 0.0010000
# Epoch [27/40], Time: 11.97s, Train Loss: 0.0943, Val Loss: 0.0941, LR: 0.0010000
# Epoch [28/40], Time: 12.05s, Train Loss: 0.0941, Val Loss: 0.0928, LR: 0.0010000
# Epoch [29/40], Time: 12.34s, Train Loss: 0.0940, Val Loss: 0.0931, LR: 0.0010000
# Epoch [30/40], Time: 11.93s, Train Loss: 0.0938, Val Loss: 0.0932, LR: 0.0010000
# Epoch [31/40], Time: 11.89s, Train Loss: 0.0935, Val Loss: 0.0927, LR: 0.0010000
# Epoch [32/40], Time: 11.92s, Train Loss: 0.0935, Val Loss: 0.0933, LR: 0.0010000
# Epoch [33/40], Time: 12.23s, Train Loss: 0.0935, Val Loss: 0.0948, LR: 0.0010000
# Epoch [34/40], Time: 12.05s, Train Loss: 0.0932, Val Loss: 0.0927, LR: 0.0010000
# Epoch [35/40], Time: 12.17s, Train Loss: 0.0933, Val Loss: 0.0926, LR: 0.0010000
# Epoch [36/40], Time: 12.01s, Train Loss: 0.0931, Val Loss: 0.0930, LR: 0.0010000
# Epoch [37/40], Time: 12.18s, Train Loss: 0.0928, Val Loss: 0.0920, LR: 0.0010000
# Epoch [38/40], Time: 12.57s, Train Loss: 0.0927, Val Loss: 0.0934, LR: 0.0010000
# Epoch [39/40], Time: 12.61s, Train Loss: 0.0927, Val Loss: 0.0922, LR: 0.0010000
# Epoch [40/40], Time: 12.12s, Train Loss: 0.0925, Val Loss: 0.0929, LR: 0.0010000

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
for param in model.encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
pretrained_encoder = model.encoder
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  c10_train_loader,
                                                                           val_loader = c10_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-3)
# Out:
# Epoch [1/30], Time: 14.71s, Train Loss: 1.6404, Train Accuracy: 41.34%, Val Accuracy: 47.91%, LR: 0.001000
# Epoch [2/30], Time: 14.37s, Train Loss: 1.4224, Train Accuracy: 49.02%, Val Accuracy: 50.90%, LR: 0.001000
# Epoch [3/30], Time: 14.43s, Train Loss: 1.3316, Train Accuracy: 52.42%, Val Accuracy: 52.65%, LR: 0.001000
# Epoch [4/30], Time: 14.45s, Train Loss: 1.2733, Train Accuracy: 54.40%, Val Accuracy: 54.10%, LR: 0.001000
# Epoch [5/30], Time: 14.51s, Train Loss: 1.2203, Train Accuracy: 56.62%, Val Accuracy: 55.11%, LR: 0.001000
# Epoch [6/30], Time: 14.42s, Train Loss: 1.1847, Train Accuracy: 57.82%, Val Accuracy: 55.63%, LR: 0.001000
# Epoch [7/30], Time: 14.37s, Train Loss: 1.1451, Train Accuracy: 58.95%, Val Accuracy: 55.17%, LR: 0.001000
# Epoch [8/30], Time: 14.27s, Train Loss: 1.1170, Train Accuracy: 60.27%, Val Accuracy: 56.19%, LR: 0.001000
# Epoch [9/30], Time: 14.34s, Train Loss: 1.0879, Train Accuracy: 61.26%, Val Accuracy: 56.67%, LR: 0.001000
# Epoch [10/30], Time: 14.34s, Train Loss: 1.0610, Train Accuracy: 61.97%, Val Accuracy: 56.15%, LR: 0.000125
# Epoch [11/30], Time: 14.38s, Train Loss: 0.9675, Train Accuracy: 65.47%, Val Accuracy: 57.27%, LR: 0.000125
# Epoch [12/30], Time: 14.39s, Train Loss: 0.9347, Train Accuracy: 66.63%, Val Accuracy: 57.79%, LR: 0.000125
# Epoch [13/30], Time: 14.37s, Train Loss: 0.9125, Train Accuracy: 67.38%, Val Accuracy: 57.96%, LR: 0.000125
# Epoch [14/30], Time: 14.52s, Train Loss: 0.8975, Train Accuracy: 67.76%, Val Accuracy: 58.01%, LR: 0.000125
# Epoch [15/30], Time: 14.48s, Train Loss: 0.8825, Train Accuracy: 68.29%, Val Accuracy: 57.99%, LR: 0.000125
# Epoch [16/30], Time: 14.63s, Train Loss: 0.8782, Train Accuracy: 68.73%, Val Accuracy: 58.18%, LR: 0.000125
# Epoch [17/30], Time: 14.53s, Train Loss: 0.8664, Train Accuracy: 68.89%, Val Accuracy: 58.45%, LR: 0.000125
# Epoch [18/30], Time: 14.86s, Train Loss: 0.8581, Train Accuracy: 69.38%, Val Accuracy: 58.24%, LR: 0.000125
# Epoch [19/30], Time: 14.49s, Train Loss: 0.8500, Train Accuracy: 69.86%, Val Accuracy: 58.58%, LR: 0.000125
# Epoch [20/30], Time: 14.71s, Train Loss: 0.8441, Train Accuracy: 69.83%, Val Accuracy: 58.41%, LR: 0.000016
# Epoch [21/30], Time: 15.00s, Train Loss: 0.8288, Train Accuracy: 70.36%, Val Accuracy: 58.41%, LR: 0.000016
# Epoch [22/30], Time: 15.55s, Train Loss: 0.8234, Train Accuracy: 70.83%, Val Accuracy: 58.48%, LR: 0.000016
# Epoch [23/30], Time: 14.48s, Train Loss: 0.8274, Train Accuracy: 70.47%, Val Accuracy: 58.35%, LR: 0.000016
# Epoch [24/30], Time: 14.76s, Train Loss: 0.8209, Train Accuracy: 70.73%, Val Accuracy: 58.33%, LR: 0.000016
# Epoch [25/30], Time: 14.71s, Train Loss: 0.8175, Train Accuracy: 70.89%, Val Accuracy: 58.53%, LR: 0.000016
# Epoch [26/30], Time: 14.73s, Train Loss: 0.8147, Train Accuracy: 70.62%, Val Accuracy: 58.38%, LR: 0.000016
# Epoch [27/30], Time: 14.58s, Train Loss: 0.8130, Train Accuracy: 70.55%, Val Accuracy: 58.39%, LR: 0.000016
# Epoch [28/30], Time: 14.83s, Train Loss: 0.8152, Train Accuracy: 70.56%, Val Accuracy: 58.48%, LR: 0.000016
# Epoch [29/30], Time: 14.56s, Train Loss: 0.8114, Train Accuracy: 70.83%, Val Accuracy: 58.60%, LR: 0.000016
# Epoch [30/30], Time: 14.58s, Train Loss: 0.8144, Train Accuracy: 70.85%, Val Accuracy: 58.51%, LR: 0.000002

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=c10_test_loader)
# Out:
# Test Accuracy: 58.65%

# %% [markdown]
# ## Saving model

# %%
save_pretrained_model(path = base_path + 'cifar.pth',
                      encoder = model.encoder,
                      classifier = classifier,
                      decoder = model.decoder)
