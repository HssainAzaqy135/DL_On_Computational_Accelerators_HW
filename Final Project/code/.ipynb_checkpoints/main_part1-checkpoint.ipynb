# %% [markdown]
# # Main For Part 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
from matplotlib import pyplot as plt
# Needed for training
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import random_split, DataLoader
from torch.utils.data.dataset import Subset
# Models
from models_part1 import FinalClassifier , MNISTAutoencoder, CIFAR10Autoencoder
from models_testing import  plot_accuracies,plot_losses,test_classifier,test_classifyingAutoEncoder
# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # MNIST

# %% [markdown]
# # Preparing Data

# %%
mnist_path = "./mnist_data"

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

train_dataset = torchvision.datasets.MNIST(
    root=mnist_path,  
    train=True,       
    transform=transform,  # Apply transformations here
    download=True     
)

test_dataset = torchvision.datasets.MNIST(
    root=mnist_path,
    train=False,  
    transform=transform,  # Apply same transformations for test data
    download=True
)

print("MNIST dataset downloaded successfully!")
# Out:
# MNIST dataset downloaded successfully!

# %%
train_size = 50_000
val_size = 10_000

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

print(f"Train size: {len(train_dataset)}, Validation size: {len(val_dataset)}, Test size: {len(test_dataset)}")


batch_size = 64

# Create DataLoaders
mnist_train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
mnist_val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
mnist_test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print("DataLoaders created successfully!")

images, labels = next(iter(mnist_train_loader))
print(f"Batch shape: {images.shape}, Labels: {labels[:5]}")
# Out:
# Train size: 50000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!
# Batch shape: torch.Size([64, 1, 28, 28]), Labels: tensor([3, 3, 2, 6, 3])

# %% [markdown]
# # Experiment

# %%
# Model initialization
model = MNISTAutoencoder(latent_dim=128).to(device)

train_losses,val_losses = model.train_autoencoder(train_loader= mnist_train_loader,
                       val_loader=mnist_val_loader,
                       num_epochs=40,
                       learning_rate=1e-3,
                       weight_decay= 1e-3)
# Out:
# Epoch [1/40], Time: 14.89s, Train Loss: 0.0884, Val Loss: 0.0362, LR: 0.0010000
# Epoch [2/40], Time: 10.04s, Train Loss: 0.0425, Val Loss: 0.0314, LR: 0.0010000
# Epoch [3/40], Time: 10.11s, Train Loss: 0.0396, Val Loss: 0.0289, LR: 0.0010000
# Epoch [4/40], Time: 11.43s, Train Loss: 0.0380, Val Loss: 0.0281, LR: 0.0010000
# Epoch [5/40], Time: 11.23s, Train Loss: 0.0368, Val Loss: 0.0272, LR: 0.0010000
# Epoch [6/40], Time: 10.44s, Train Loss: 0.0360, Val Loss: 0.0265, LR: 0.0010000
# Epoch [7/40], Time: 10.00s, Train Loss: 0.0352, Val Loss: 0.0256, LR: 0.0010000
# Epoch [8/40], Time: 9.89s, Train Loss: 0.0347, Val Loss: 0.0251, LR: 0.0010000
# Epoch [9/40], Time: 9.95s, Train Loss: 0.0342, Val Loss: 0.0250, LR: 0.0010000
# Epoch [10/40], Time: 10.16s, Train Loss: 0.0338, Val Loss: 0.0244, LR: 0.0010000
# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
pretrained_encoder = model.encoder
for param in pretrained_encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  mnist_train_loader,
                                                                           val_loader = mnist_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-3)
# Out:
# Epoch [1/30], Time: 12.12s, Train Loss: 0.2733, Train Accuracy: 91.92%, Val Accuracy: 96.36%, LR: 0.001000
# Epoch [2/30], Time: 11.89s, Train Loss: 0.1268, Train Accuracy: 96.08%, Val Accuracy: 97.42%, LR: 0.001000
# Epoch [3/30], Time: 13.18s, Train Loss: 0.0909, Train Accuracy: 97.17%, Val Accuracy: 97.66%, LR: 0.001000
# Epoch [4/30], Time: 12.03s, Train Loss: 0.0726, Train Accuracy: 97.73%, Val Accuracy: 97.71%, LR: 0.001000
# Epoch [5/30], Time: 11.92s, Train Loss: 0.0640, Train Accuracy: 97.94%, Val Accuracy: 97.70%, LR: 0.001000
# Epoch [6/30], Time: 11.85s, Train Loss: 0.0553, Train Accuracy: 98.20%, Val Accuracy: 97.56%, LR: 0.001000
# Epoch [7/30], Time: 11.94s, Train Loss: 0.0499, Train Accuracy: 98.33%, Val Accuracy: 97.87%, LR: 0.001000
# Epoch [8/30], Time: 11.98s, Train Loss: 0.0455, Train Accuracy: 98.46%, Val Accuracy: 97.89%, LR: 0.001000
# Epoch [9/30], Time: 11.95s, Train Loss: 0.0429, Train Accuracy: 98.56%, Val Accuracy: 98.05%, LR: 0.001000
# Epoch [10/30], Time: 11.96s, Train Loss: 0.0396, Train Accuracy: 98.59%, Val Accuracy: 98.16%, LR: 0.000125
# Epoch [11/30], Time: 12.05s, Train Loss: 0.0269, Train Accuracy: 99.14%, Val Accuracy: 98.27%, LR: 0.000125
# Epoch [12/30], Time: 11.83s, Train Loss: 0.0209, Train Accuracy: 99.36%, Val Accuracy: 98.23%, LR: 0.000125
# Epoch [13/30], Time: 11.89s, Train Loss: 0.0184, Train Accuracy: 99.39%, Val Accuracy: 98.36%, LR: 0.000125
# Epoch [14/30], Time: 12.12s, Train Loss: 0.0161, Train Accuracy: 99.47%, Val Accuracy: 98.38%, LR: 0.000125
# Epoch [15/30], Time: 11.90s, Train Loss: 0.0148, Train Accuracy: 99.54%, Val Accuracy: 98.40%, LR: 0.000125
# Epoch [16/30], Time: 11.87s, Train Loss: 0.0131, Train Accuracy: 99.60%, Val Accuracy: 98.40%, LR: 0.000125
# Epoch [17/30], Time: 11.88s, Train Loss: 0.0125, Train Accuracy: 99.62%, Val Accuracy: 98.41%, LR: 0.000125
# Epoch [18/30], Time: 11.76s, Train Loss: 0.0116, Train Accuracy: 99.64%, Val Accuracy: 98.37%, LR: 0.000125
# Epoch [19/30], Time: 11.77s, Train Loss: 0.0121, Train Accuracy: 99.62%, Val Accuracy: 98.34%, LR: 0.000125
# Epoch [20/30], Time: 11.83s, Train Loss: 0.0109, Train Accuracy: 99.65%, Val Accuracy: 98.40%, LR: 0.000016
# Epoch [21/30], Time: 11.81s, Train Loss: 0.0096, Train Accuracy: 99.69%, Val Accuracy: 98.40%, LR: 0.000016
# Epoch [22/30], Time: 11.84s, Train Loss: 0.0096, Train Accuracy: 99.73%, Val Accuracy: 98.39%, LR: 0.000016
# Epoch [23/30], Time: 12.10s, Train Loss: 0.0092, Train Accuracy: 99.73%, Val Accuracy: 98.42%, LR: 0.000016
# Epoch [24/30], Time: 11.90s, Train Loss: 0.0086, Train Accuracy: 99.75%, Val Accuracy: 98.44%, LR: 0.000016
# Epoch [25/30], Time: 12.10s, Train Loss: 0.0090, Train Accuracy: 99.69%, Val Accuracy: 98.40%, LR: 0.000016
# Epoch [26/30], Time: 11.93s, Train Loss: 0.0094, Train Accuracy: 99.70%, Val Accuracy: 98.39%, LR: 0.000016
# Epoch [27/30], Time: 11.79s, Train Loss: 0.0085, Train Accuracy: 99.75%, Val Accuracy: 98.45%, LR: 0.000016
# Epoch [28/30], Time: 11.98s, Train Loss: 0.0083, Train Accuracy: 99.74%, Val Accuracy: 98.40%, LR: 0.000016
# Epoch [29/30], Time: 11.81s, Train Loss: 0.0088, Train Accuracy: 99.73%, Val Accuracy: 98.46%, LR: 0.000016
# Epoch [30/30], Time: 11.84s, Train Loss: 0.0079, Train Accuracy: 99.78%, Val Accuracy: 98.49%, LR: 0.000002

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=mnist_test_loader)
# Out:
# Test Accuracy: 98.57%

# %% [markdown]
# # Cifar10

# %% [markdown]
# # Preparing data

# %%
cifar10_path = "./cifar10_data"

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5,0.5,0.5], std=[0.5,0.5,0.5])
])

c10_full_train_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,  
    train=True,       
    transform=transform,
    download=True     
)

c10_test_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,
    train=False,  
    transform=transform,
    download=True
)

print("CIFAR-10 dataset downloaded successfully!")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CIFAR-10 dataset downloaded successfully!

# %%
train_size = 40_000
val_size = 10_000

c10_train_dataset, c10_val_dataset = random_split(c10_full_train_dataset, [train_size, val_size])

# Check dataset sizes
print(f"Train size: {len(c10_train_dataset)}, Validation size: {len(c10_val_dataset)}, Test size: {len(c10_test_dataset)}")

# Define batch size
batch_size = 64

# Create DataLoaders
c10_train_loader = DataLoader(c10_train_dataset, batch_size=batch_size, shuffle=True)
c10_val_loader = DataLoader(c10_val_dataset, batch_size=batch_size, shuffle=False)
c10_test_loader = DataLoader(c10_test_dataset, batch_size=batch_size, shuffle=False)

print("DataLoaders created successfully!")

# Get a batch of images and labels from the train_loader
images, labels = next(iter(c10_train_loader))
print(f"Batch shape: {images.shape}, Labels (first 5): {labels[:5]}")
# Out:
# Train size: 40000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!
# Batch shape: torch.Size([64, 3, 32, 32]), Labels (first 5): tensor([7, 8, 8, 5, 0])

# Epoch [27/40], Time: 11.83s, Train Loss: 0.0939, Val Loss: 0.0922, LR: 0.0010000
# Epoch [28/40], Time: 11.75s, Train Loss: 0.0940, Val Loss: 0.0928, LR: 0.0010000
# Epoch [29/40], Time: 11.60s, Train Loss: 0.0939, Val Loss: 0.0935, LR: 0.0010000
# Epoch [30/40], Time: 11.65s, Train Loss: 0.0936, Val Loss: 0.0921, LR: 0.0010000
# Epoch [31/40], Time: 11.76s, Train Loss: 0.0935, Val Loss: 0.0932, LR: 0.0010000
# Epoch [32/40], Time: 11.70s, Train Loss: 0.0932, Val Loss: 0.0922, LR: 0.0010000
# Epoch [33/40], Time: 11.70s, Train Loss: 0.0934, Val Loss: 0.0921, LR: 0.0010000
# Epoch [34/40], Time: 11.65s, Train Loss: 0.0931, Val Loss: 0.0917, LR: 0.0010000
# Epoch [35/40], Time: 13.09s, Train Loss: 0.0930, Val Loss: 0.0923, LR: 0.0010000
# Epoch [36/40], Time: 12.18s, Train Loss: 0.0929, Val Loss: 0.0919, LR: 0.0010000
# Epoch [37/40], Time: 11.71s, Train Loss: 0.0928, Val Loss: 0.0921, LR: 0.0010000
# Epoch [38/40], Time: 11.88s, Train Loss: 0.0927, Val Loss: 0.0915, LR: 0.0010000
# Epoch [39/40], Time: 11.72s, Train Loss: 0.0924, Val Loss: 0.0917, LR: 0.0010000
# Epoch [40/40], Time: 11.60s, Train Loss: 0.0926, Val Loss: 0.0917, LR: 0.0010000

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
for param in model.encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
pretrained_encoder = model.encoder
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  c10_train_loader,
                                                                           val_loader = c10_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-3)
# Out:
# Epoch [1/30], Time: 14.31s, Train Loss: 1.6429, Train Accuracy: 41.73%, Val Accuracy: 49.52%, LR: 0.001000
# Epoch [2/30], Time: 14.30s, Train Loss: 1.4301, Train Accuracy: 49.03%, Val Accuracy: 51.81%, LR: 0.001000
# Epoch [3/30], Time: 14.20s, Train Loss: 1.3465, Train Accuracy: 51.96%, Val Accuracy: 53.54%, LR: 0.001000
# Epoch [4/30], Time: 14.44s, Train Loss: 1.2821, Train Accuracy: 54.27%, Val Accuracy: 53.93%, LR: 0.001000
# Epoch [5/30], Time: 13.95s, Train Loss: 1.2299, Train Accuracy: 56.07%, Val Accuracy: 54.60%, LR: 0.001000
# Epoch [6/30], Time: 14.98s, Train Loss: 1.1908, Train Accuracy: 57.26%, Val Accuracy: 55.54%, LR: 0.001000
# Epoch [7/30], Time: 15.20s, Train Loss: 1.1599, Train Accuracy: 58.76%, Val Accuracy: 55.47%, LR: 0.001000
# Epoch [8/30], Time: 13.84s, Train Loss: 1.1286, Train Accuracy: 59.70%, Val Accuracy: 56.37%, LR: 0.001000
# Epoch [9/30], Time: 14.03s, Train Loss: 1.0955, Train Accuracy: 60.72%, Val Accuracy: 56.18%, LR: 0.001000
# Epoch [10/30], Time: 14.03s, Train Loss: 1.0650, Train Accuracy: 61.77%, Val Accuracy: 56.92%, LR: 0.000125
# Epoch [11/30], Time: 14.23s, Train Loss: 0.9711, Train Accuracy: 65.61%, Val Accuracy: 58.16%, LR: 0.000125
# Epoch [12/30], Time: 14.08s, Train Loss: 0.9386, Train Accuracy: 66.69%, Val Accuracy: 58.18%, LR: 0.000125
# Epoch [13/30], Time: 13.84s, Train Loss: 0.9127, Train Accuracy: 67.40%, Val Accuracy: 58.37%, LR: 0.000125
# Epoch [14/30], Time: 13.90s, Train Loss: 0.9047, Train Accuracy: 67.64%, Val Accuracy: 58.78%, LR: 0.000125
# Epoch [15/30], Time: 13.79s, Train Loss: 0.8893, Train Accuracy: 68.27%, Val Accuracy: 58.50%, LR: 0.000125
# Epoch [16/30], Time: 13.83s, Train Loss: 0.8755, Train Accuracy: 68.72%, Val Accuracy: 58.47%, LR: 0.000125
# Epoch [17/30], Time: 13.80s, Train Loss: 0.8713, Train Accuracy: 68.79%, Val Accuracy: 58.52%, LR: 0.000125
# Epoch [18/30], Time: 13.66s, Train Loss: 0.8608, Train Accuracy: 69.13%, Val Accuracy: 58.54%, LR: 0.000125
# Epoch [19/30], Time: 13.73s, Train Loss: 0.8605, Train Accuracy: 69.32%, Val Accuracy: 58.72%, LR: 0.000125
# Epoch [20/30], Time: 13.94s, Train Loss: 0.8416, Train Accuracy: 69.72%, Val Accuracy: 58.76%, LR: 0.000016
# Epoch [21/30], Time: 13.98s, Train Loss: 0.8242, Train Accuracy: 70.53%, Val Accuracy: 58.56%, LR: 0.000016
# Epoch [22/30], Time: 14.01s, Train Loss: 0.8297, Train Accuracy: 70.33%, Val Accuracy: 58.75%, LR: 0.000016
# Epoch [23/30], Time: 14.01s, Train Loss: 0.8220, Train Accuracy: 70.66%, Val Accuracy: 58.91%, LR: 0.000016
# Epoch [24/30], Time: 14.07s, Train Loss: 0.8178, Train Accuracy: 70.86%, Val Accuracy: 58.77%, LR: 0.000016
# Epoch [25/30], Time: 14.40s, Train Loss: 0.8184, Train Accuracy: 70.66%, Val Accuracy: 58.79%, LR: 0.000016
# Epoch [26/30], Time: 14.08s, Train Loss: 0.8191, Train Accuracy: 70.49%, Val Accuracy: 58.68%, LR: 0.000016
# Epoch [27/30], Time: 13.90s, Train Loss: 0.8187, Train Accuracy: 70.61%, Val Accuracy: 58.96%, LR: 0.000016
# Epoch [28/30], Time: 14.01s, Train Loss: 0.8194, Train Accuracy: 70.79%, Val Accuracy: 58.88%, LR: 0.000016
# Epoch [29/30], Time: 14.02s, Train Loss: 0.8164, Train Accuracy: 71.10%, Val Accuracy: 59.03%, LR: 0.000016
# Epoch [30/30], Time: 13.93s, Train Loss: 0.8174, Train Accuracy: 70.62%, Val Accuracy: 58.95%, LR: 0.000002

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=c10_test_loader)
# Out:
# Test Accuracy: 58.75%
