# %% [markdown]
# # Main For Part 3

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
from matplotlib import pyplot as plt
# Needed for training
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import random_split, DataLoader
from torch.utils.data.dataset import Subset
# Models
from models_part1 import FinalClassifier
from models_part3_testing import NTXentLoss,MnistSimCLR,Cifar10SimCLR
from models_testing import  plot_accuracies,plot_losses,test_classifier,test_classifyingAutoEncoder
from models_testing import create_model_folders,PretrainedModel,save_pretrained_model
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
base_path = 'trained_models/part_3/'

# %% [markdown]
# # MNIST

# %% [markdown]
# # Preparing Data

# %%
mnist_path = "./mnist_data"

train_transform = transforms.Compose([
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.MNIST(
    root=mnist_path,  
    train=True,       
    transform=train_transform,  # Apply train transformations
    download=True     
)

test_dataset = torchvision.datasets.MNIST(
    root=mnist_path,
    train=False,  
    transform=test_transform,  # Apply test transformations
    download=True
)

print("MNIST dataset downloaded successfully!")
# Out:
# MNIST dataset downloaded successfully!

# %%
train_size = 50_000
val_size = 10_000
batch_size = 128


train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

print(f"Train size: {len(train_dataset)}, Validation size: {len(val_dataset)}, Test size: {len(test_dataset)}")

# Create DataLoaders
mnist_train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
mnist_val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
mnist_test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print("DataLoaders created successfully!")

# images, labels = next(iter(mnist_train_loader))
# print(f"Batch shape: {images.shape}, Labels: {labels[:5]}")
# Out:
# Train size: 50000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!

# %% [markdown]
# # Experiment

# %%
model = MnistSimCLR(latent_dim=128,dropout_prob=0.1,temperature = 0.07).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader= mnist_train_loader,
                       val_loader=mnist_val_loader,
                       num_epochs=40,
                       learning_rate=1e-3,
                       weight_decay= 1e-3)
# Out:
# Epoch [1/40], Time: 5.36s, Train Loss: 2.5578, Val Loss: 1.5433, LR: 0.001000
# Epoch [2/40], Time: 5.39s, Train Loss: 1.7560, Val Loss: 1.5749, LR: 0.001000
# Epoch [3/40], Time: 5.39s, Train Loss: 1.6082, Val Loss: 1.6512, LR: 0.001000
# Epoch [4/40], Time: 5.41s, Train Loss: 1.5054, Val Loss: 1.5998, LR: 0.001000
# Epoch [5/40], Time: 5.35s, Train Loss: 1.4904, Val Loss: 2.2061, LR: 0.001000
# Epoch [6/40], Time: 5.39s, Train Loss: 1.4444, Val Loss: 1.6326, LR: 0.001000
# Epoch [7/40], Time: 5.37s, Train Loss: 1.4378, Val Loss: 1.7054, LR: 0.000125
# Epoch [8/40], Time: 5.40s, Train Loss: 1.3455, Val Loss: 1.5652, LR: 0.000125
# Epoch [9/40], Time: 5.41s, Train Loss: 1.3288, Val Loss: 2.1130, LR: 0.000125
# Epoch [39/40], Time: 5.38s, Train Loss: 1.2759, Val Loss: 1.7059, LR: 0.000000
# Epoch [40/40], Time: 5.39s, Train Loss: 1.2819, Val Loss: 1.5737, LR: 0.000000

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
pretrained_encoder = model.encoder
for param in pretrained_encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  mnist_train_loader,
                                                                           val_loader = mnist_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-4)
# Out:
# Epoch [1/30], Time: 3.92s, Train Loss: 0.5072, Train Accuracy: 86.91%, Val Accuracy: 94.90%, LR: 0.000100
# Epoch [2/30], Time: 3.88s, Train Loss: 0.2027, Train Accuracy: 94.78%, Val Accuracy: 96.43%, LR: 0.000100
# Epoch [3/30], Time: 3.86s, Train Loss: 0.1413, Train Accuracy: 96.23%, Val Accuracy: 97.06%, LR: 0.000100
# Epoch [4/30], Time: 3.83s, Train Loss: 0.1143, Train Accuracy: 96.80%, Val Accuracy: 97.38%, LR: 0.000100
# Epoch [5/30], Time: 3.87s, Train Loss: 0.0974, Train Accuracy: 97.18%, Val Accuracy: 97.56%, LR: 0.000100
# Epoch [6/30], Time: 3.82s, Train Loss: 0.0865, Train Accuracy: 97.49%, Val Accuracy: 97.71%, LR: 0.000100
# Epoch [7/30], Time: 3.86s, Train Loss: 0.0779, Train Accuracy: 97.60%, Val Accuracy: 97.92%, LR: 0.000100
# Epoch [8/30], Time: 3.84s, Train Loss: 0.0729, Train Accuracy: 97.80%, Val Accuracy: 98.02%, LR: 0.000100
# Epoch [9/30], Time: 3.79s, Train Loss: 0.0681, Train Accuracy: 97.97%, Val Accuracy: 98.00%, LR: 0.000100
# Epoch [10/30], Time: 3.80s, Train Loss: 0.0617, Train Accuracy: 98.08%, Val Accuracy: 98.18%, LR: 0.000013
# Epoch [11/30], Time: 3.80s, Train Loss: 0.0539, Train Accuracy: 98.42%, Val Accuracy: 98.21%, LR: 0.000013
# Epoch [12/30], Time: 3.88s, Train Loss: 0.0532, Train Accuracy: 98.36%, Val Accuracy: 98.21%, LR: 0.000013
# Epoch [13/30], Time: 3.83s, Train Loss: 0.0519, Train Accuracy: 98.44%, Val Accuracy: 98.33%, LR: 0.000013
# Epoch [14/30], Time: 3.86s, Train Loss: 0.0508, Train Accuracy: 98.43%, Val Accuracy: 98.41%, LR: 0.000013
# Epoch [15/30], Time: 3.82s, Train Loss: 0.0493, Train Accuracy: 98.48%, Val Accuracy: 98.31%, LR: 0.000013
# Epoch [16/30], Time: 3.81s, Train Loss: 0.0489, Train Accuracy: 98.52%, Val Accuracy: 98.33%, LR: 0.000013
# Epoch [17/30], Time: 3.86s, Train Loss: 0.0481, Train Accuracy: 98.51%, Val Accuracy: 98.36%, LR: 0.000013
# Epoch [18/30], Time: 3.84s, Train Loss: 0.0472, Train Accuracy: 98.56%, Val Accuracy: 98.41%, LR: 0.000013
# Epoch [19/30], Time: 3.91s, Train Loss: 0.0474, Train Accuracy: 98.51%, Val Accuracy: 98.38%, LR: 0.000013
# Epoch [20/30], Time: 3.87s, Train Loss: 0.0454, Train Accuracy: 98.60%, Val Accuracy: 98.33%, LR: 0.000002
# Epoch [21/30], Time: 3.87s, Train Loss: 0.0460, Train Accuracy: 98.63%, Val Accuracy: 98.31%, LR: 0.000002
# Epoch [22/30], Time: 3.86s, Train Loss: 0.0468, Train Accuracy: 98.56%, Val Accuracy: 98.35%, LR: 0.000002
# Epoch [23/30], Time: 3.82s, Train Loss: 0.0444, Train Accuracy: 98.67%, Val Accuracy: 98.33%, LR: 0.000002
# Epoch [24/30], Time: 3.85s, Train Loss: 0.0453, Train Accuracy: 98.68%, Val Accuracy: 98.38%, LR: 0.000002
# Epoch [25/30], Time: 3.83s, Train Loss: 0.0456, Train Accuracy: 98.62%, Val Accuracy: 98.35%, LR: 0.000002
# Epoch [26/30], Time: 3.83s, Train Loss: 0.0442, Train Accuracy: 98.63%, Val Accuracy: 98.36%, LR: 0.000002
# Epoch [27/30], Time: 3.89s, Train Loss: 0.0452, Train Accuracy: 98.60%, Val Accuracy: 98.33%, LR: 0.000002
# Epoch [28/30], Time: 3.96s, Train Loss: 0.0454, Train Accuracy: 98.57%, Val Accuracy: 98.35%, LR: 0.000002
# Epoch [29/30], Time: 3.89s, Train Loss: 0.0459, Train Accuracy: 98.60%, Val Accuracy: 98.35%, LR: 0.000002
# Epoch [30/30], Time: 3.91s, Train Loss: 0.0462, Train Accuracy: 98.61%, Val Accuracy: 98.38%, LR: 0.000000

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=mnist_test_loader)
# Out:
# Test Accuracy: 98.54%
# 98.54

# %% [markdown]
# ## Saving model

# %%
save_pretrained_model(path = base_path + 'mnist_test.pth',
                      encoder = model.encoder,
                      classifier = classifier,
                      decoder = None)

# %%
from utils import plot_tsne
pretrained_model = torch.load(f"trained_models/part_3/mnist_test.pth")
plot_tsne(model = pretrained_model.encoder,
                      dataloader= mnist_test_loader,
                      device = pretrained_model.get_device(),
                      title='part 3 testing')
# Out:
# C:\Users\Tomer\AppData\Local\Temp\ipykernel_132724\1143904121.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_model = torch.load(f"trained_models/part_3/mnist_test.pth")

# %%
import matplotlib.image as mpimg
img_path_1 = 'tsne_plots/image_tsnetsne part 3 testing.png'  # Adjust path based on what plot_tsne saves
img_1 = mpimg.imread(img_path_1)
plt.imshow(img)
plt.axis('off')  # Hide axes for a clean display
plt.show()  # Display the plot


img_path_2 = 'tsne_plots/latent_tsne_tsne part 3 testing.png'  # Adjust path based on what plot_tsne saves
img_2 = mpimg.imread(img_path_2)
plt.imshow(img_2)
plt.axis('off')  # Hide axes for a clean display
plt.show()  # Display the plot

# %% [markdown]
# # Cifar10

# %% [markdown]
# # Preparing data

# %%
cifar10_path = "./cifar10_data"

train_transform = transforms.Compose([
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
])

c10_full_train_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,  
    train=True,       
    transform=train_transform,
    download=True     
)

c10_test_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,
    train=False,  
    transform=test_transform,
    download=True
)

print("CIFAR-10 dataset downloaded successfully!")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CIFAR-10 dataset downloaded successfully!

# %%
train_size = 40_000
val_size = 10_000
batch_size = 128

c10_train_dataset, c10_val_dataset = random_split(c10_full_train_dataset, [train_size, val_size])

# Check dataset sizes
print(f"Train size: {len(c10_train_dataset)}, Validation size: {len(c10_val_dataset)}, Test size: {len(c10_test_dataset)}")



# Create DataLoaders
c10_train_loader = DataLoader(c10_train_dataset, batch_size=batch_size, shuffle=True)
c10_val_loader = DataLoader(c10_val_dataset, batch_size=batch_size, shuffle=False)
c10_test_loader = DataLoader(c10_test_dataset, batch_size=batch_size, shuffle=False)

print("DataLoaders created successfully!")

# Get a batch of images and labels from the train_loader
images, labels = next(iter(c10_train_loader))
print(f"Batch shape: {images.shape}, Labels (first 5): {labels[:5]}")
# Out:
# Train size: 40000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!
# Batch shape: torch.Size([128, 3, 32, 32]), Labels (first 5): tensor([1, 9, 5, 2, 6])

# %% [markdown]
# # Experiment

# %%
model = Cifar10SimCLR(latent_dim=128,
                      dropout_prob=0.1,
                      temperature=0.07).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader = c10_train_loader,
                        val_loader = c10_val_loader,
                        num_epochs=60,
                        learning_rate=1e-3,
                        weight_decay= 1e-3)
# Out:
# Initializing weights ....
# Initializing weights DONE
# Epoch [1/60], Time: 5.99s, Train Loss: 2.2030, Val Loss: 1.1847, LR: 0.001000
# Epoch [2/60], Time: 5.69s, Train Loss: 1.7402, Val Loss: 1.1636, LR: 0.001000
# Epoch [3/60], Time: 5.71s, Train Loss: 1.6101, Val Loss: 1.1596, LR: 0.001000
# Epoch [4/60], Time: 5.66s, Train Loss: 1.5567, Val Loss: 1.1869, LR: 0.001000
# Epoch [5/60], Time: 5.69s, Train Loss: 1.5056, Val Loss: 1.1564, LR: 0.001000
# Epoch [6/60], Time: 5.69s, Train Loss: 1.4493, Val Loss: 1.1576, LR: 0.001000
# Epoch [7/60], Time: 5.69s, Train Loss: 1.4505, Val Loss: 1.1572, LR: 0.001000
# Epoch [8/60], Time: 5.68s, Train Loss: 1.4182, Val Loss: 1.1372, LR: 0.001000
# Epoch [9/60], Time: 5.69s, Train Loss: 1.4044, Val Loss: 1.1349, LR: 0.001000
# Epoch [10/60], Time: 5.67s, Train Loss: 1.3748, Val Loss: 1.1534, LR: 0.001000
# Epoch [11/60], Time: 5.66s, Train Loss: 1.3663, Val Loss: 1.1335, LR: 0.001000
# Epoch [12/60], Time: 5.65s, Train Loss: 1.3609, Val Loss: 1.1370, LR: 0.001000
# Epoch [42/60], Time: 5.69s, Train Loss: 1.2497, Val Loss: 1.1255, LR: 0.000002
# Epoch [43/60], Time: 5.71s, Train Loss: 1.2399, Val Loss: 1.1269, LR: 0.000002
# Epoch [44/60], Time: 5.68s, Train Loss: 1.2485, Val Loss: 1.1257, LR: 0.000002
# Epoch [45/60], Time: 5.74s, Train Loss: 1.2541, Val Loss: 1.1262, LR: 0.000002
# Epoch [46/60], Time: 5.75s, Train Loss: 1.2438, Val Loss: 1.1242, LR: 0.000002
# Epoch [47/60], Time: 5.72s, Train Loss: 1.2590, Val Loss: 1.1271, LR: 0.000002
# Epoch [48/60], Time: 5.77s, Train Loss: 1.2519, Val Loss: 1.1196, LR: 0.000002
# Epoch [49/60], Time: 5.76s, Train Loss: 1.2543, Val Loss: 1.1228, LR: 0.000002
# Epoch [50/60], Time: 5.71s, Train Loss: 1.2379, Val Loss: 1.1349, LR: 0.000002
# Epoch [51/60], Time: 5.78s, Train Loss: 1.2559, Val Loss: 1.1247, LR: 0.000002
# Epoch [52/60], Time: 5.98s, Train Loss: 1.2459, Val Loss: 1.1294, LR: 0.000002
# Epoch [53/60], Time: 5.94s, Train Loss: 1.2575, Val Loss: 1.1224, LR: 0.000002
# Epoch [54/60], Time: 5.92s, Train Loss: 1.2476, Val Loss: 1.1222, LR: 0.000000
# Epoch [55/60], Time: 5.92s, Train Loss: 1.2533, Val Loss: 1.1217, LR: 0.000000
# Epoch [56/60], Time: 5.95s, Train Loss: 1.2510, Val Loss: 1.1291, LR: 0.000000
# Epoch [57/60], Time: 5.78s, Train Loss: 1.2551, Val Loss: 1.1350, LR: 0.000000
# Epoch [58/60], Time: 5.78s, Train Loss: 1.2517, Val Loss: 1.1247, LR: 0.000000
# Epoch [59/60], Time: 5.79s, Train Loss: 1.2509, Val Loss: 1.1237, LR: 0.000000
# Epoch [60/60], Time: 5.76s, Train Loss: 1.2418, Val Loss: 1.1235, LR: 0.000000

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
for param in model.encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
pretrained_encoder = model.encoder
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader = c10_train_loader,
                                                                           val_loader = c10_val_loader,
                                                                           num_epochs=40, 
                                                                           learning_rate=1e-3)
# Out:
# Epoch [1/40], Time: 4.29s, Train Loss: 1.2302, Train Accuracy: 56.70%, Val Accuracy: 62.96%, LR: 0.001000
# Epoch [2/40], Time: 4.17s, Train Loss: 1.0793, Train Accuracy: 62.01%, Val Accuracy: 64.77%, LR: 0.001000
# Epoch [3/40], Time: 4.17s, Train Loss: 1.0295, Train Accuracy: 63.88%, Val Accuracy: 65.86%, LR: 0.001000
# Epoch [4/40], Time: 4.12s, Train Loss: 0.9930, Train Accuracy: 65.05%, Val Accuracy: 66.01%, LR: 0.001000
# Epoch [5/40], Time: 4.17s, Train Loss: 0.9686, Train Accuracy: 65.86%, Val Accuracy: 66.64%, LR: 0.001000
# Epoch [28/40], Time: 4.18s, Train Loss: 0.7015, Train Accuracy: 75.19%, Val Accuracy: 69.51%, LR: 0.000016
# Epoch [29/40], Time: 4.26s, Train Loss: 0.7029, Train Accuracy: 75.06%, Val Accuracy: 69.47%, LR: 0.000016
# Epoch [30/40], Time: 4.21s, Train Loss: 0.6965, Train Accuracy: 75.28%, Val Accuracy: 69.57%, LR: 0.000002
# Epoch [31/40], Time: 4.26s, Train Loss: 0.6976, Train Accuracy: 75.23%, Val Accuracy: 69.45%, LR: 0.000002
# Epoch [32/40], Time: 4.29s, Train Loss: 0.6998, Train Accuracy: 75.15%, Val Accuracy: 69.36%, LR: 0.000002
# Epoch [33/40], Time: 4.23s, Train Loss: 0.6988, Train Accuracy: 75.11%, Val Accuracy: 69.35%, LR: 0.000002
# Epoch [34/40], Time: 4.28s, Train Loss: 0.6959, Train Accuracy: 75.18%, Val Accuracy: 69.44%, LR: 0.000002
# Epoch [35/40], Time: 4.29s, Train Loss: 0.6904, Train Accuracy: 75.36%, Val Accuracy: 69.38%, LR: 0.000002
# Epoch [36/40], Time: 4.17s, Train Loss: 0.6990, Train Accuracy: 75.11%, Val Accuracy: 69.49%, LR: 0.000002
# Epoch [37/40], Time: 4.10s, Train Loss: 0.6905, Train Accuracy: 75.46%, Val Accuracy: 69.31%, LR: 0.000002
# Epoch [38/40], Time: 4.16s, Train Loss: 0.6968, Train Accuracy: 75.17%, Val Accuracy: 69.39%, LR: 0.000002
# Epoch [39/40], Time: 4.07s, Train Loss: 0.6937, Train Accuracy: 75.27%, Val Accuracy: 69.39%, LR: 0.000002
# Epoch [40/40], Time: 4.13s, Train Loss: 0.6911, Train Accuracy: 75.43%, Val Accuracy: 69.48%, LR: 0.000000

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=c10_test_loader)
# Out:
# Test Accuracy: 68.76%
# 68.76

# %% [markdown]
# ## Saving model

# %%
save_pretrained_model(path = base_path + 'cifar_test.pth',
                      encoder = model.encoder,
                      classifier = classifier,
                      decoder = None)

# %%
from utils import plot_tsne
pretrained_model = torch.load(f"trained_models/part_3/cifar_test.pth")
plot_tsne(model = pretrained_model.encoder,
                      dataloader= c10_test_loader,
                      device = pretrained_model.get_device(),
                      title='part 3 testing cifar')
# Out:
# C:\Users\Tomer\AppData\Local\Temp\ipykernel_132724\2515227298.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_model = torch.load(f"trained_models/part_3/cifar_test.pth")

# %%
import matplotlib.image as mpimg
img_path_1 = 'tsne_plots/image_tsnepart 3 testing cifar.png'  # Adjust path based on what plot_tsne saves
img_1 = mpimg.imread(img_path_1)
plt.imshow(img)
plt.axis('off')  # Hide axes for a clean display
plt.show()  # Display the plot


img_path_2 = 'tsne_plots/latent_tsne_part 3 testing cifar.png'  # Adjust path based on what plot_tsne saves
img_2 = mpimg.imread(img_path_2)
plt.imshow(img_2)
plt.axis('off')  # Hide axes for a clean display
plt.show()  # Display the plot
