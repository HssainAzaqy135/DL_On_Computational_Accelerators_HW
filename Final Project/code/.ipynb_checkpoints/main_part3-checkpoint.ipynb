# %% [markdown]
# # Main For Part 3

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
from matplotlib import pyplot as plt
# Needed for training
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import random_split, DataLoader
from torch.utils.data.dataset import Subset
# Models
from models_part1 import FinalClassifier
from models_part3 import NTXentLoss,MnistSimCLR,Cifar10SimCLR
from models_testing import  plot_accuracies,plot_losses,test_classifier,test_classifyingAutoEncoder
# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # MNIST

# %% [markdown]
# # Preparing Data

# %%
mnist_path = "./mnist_data"

train_transform = transforms.Compose([
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.MNIST(
    root=mnist_path,  
    train=True,       
    transform=train_transform,  # Apply train transformations
    download=True     
)

test_dataset = torchvision.datasets.MNIST(
    root=mnist_path,
    train=False,  
    transform=test_transform,  # Apply test transformations
    download=True
)

print("MNIST dataset downloaded successfully!")
# Out:
# MNIST dataset downloaded successfully!

# %%
train_size = 50_000
val_size = 10_000
batch_size = 256


train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

print(f"Train size: {len(train_dataset)}, Validation size: {len(val_dataset)}, Test size: {len(test_dataset)}")

# Create DataLoaders
mnist_train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers = 1)
mnist_val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers = 1)
mnist_test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers = 1)

print("DataLoaders created successfully!")

# images, labels = next(iter(mnist_train_loader))
# print(f"Batch shape: {images.shape}, Labels: {labels[:5]}")
# Out:
# Train size: 50000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!

# %% [markdown]
# # Experiment

# %%
model = MnistSimCLR(latent_dim=128,dropout_prob=0.1,temperature = 0.1).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader= mnist_train_loader,
                       val_loader=mnist_val_loader,
                       num_epochs=40,
                       learning_rate=1e-3,
                       weight_decay= 1e-3)
# Out:
# Epoch [1/40], Time: 12.11s, Train Loss: 4.8614, Val Loss: 2.6466, LR: 0.001000
# Epoch [2/40], Time: 7.29s, Train Loss: 3.6612, Val Loss: 2.0110, LR: 0.001000
# Epoch [3/40], Time: 7.49s, Train Loss: 2.9240, Val Loss: 1.3129, LR: 0.001000
# Epoch [4/40], Time: 7.53s, Train Loss: 2.5065, Val Loss: 1.3336, LR: 0.001000
# Epoch [5/40], Time: 7.40s, Train Loss: 2.2782, Val Loss: 1.1056, LR: 0.001000
# Epoch [6/40], Time: 7.37s, Train Loss: 2.1361, Val Loss: 0.8815, LR: 0.001000
# Epoch [7/40], Time: 7.44s, Train Loss: 1.9271, Val Loss: 0.9469, LR: 0.001000
# Epoch [8/40], Time: 7.29s, Train Loss: 1.9344, Val Loss: 0.9140, LR: 0.001000
# Epoch [9/40], Time: 7.65s, Train Loss: 1.7502, Val Loss: 0.6935, LR: 0.001000
# Epoch [10/40], Time: 7.52s, Train Loss: 1.6178, Val Loss: 0.6260, LR: 0.000125
# Epoch [11/40], Time: 7.54s, Train Loss: 1.4209, Val Loss: 0.5131, LR: 0.000125
# Epoch [12/40], Time: 7.37s, Train Loss: 1.3634, Val Loss: 0.5273, LR: 0.000125
# Epoch [13/40], Time: 7.41s, Train Loss: 1.2918, Val Loss: 0.5001, LR: 0.000125
# Epoch [14/40], Time: 7.36s, Train Loss: 1.2273, Val Loss: 0.4824, LR: 0.000125
# Epoch [15/40], Time: 7.37s, Train Loss: 1.2984, Val Loss: 0.4804, LR: 0.000125
# Epoch [16/40], Time: 7.31s, Train Loss: 1.2672, Val Loss: 0.4772, LR: 0.000125
# Epoch [17/40], Time: 7.42s, Train Loss: 1.2735, Val Loss: 0.4695, LR: 0.000125
# Epoch [18/40], Time: 7.50s, Train Loss: 1.2546, Val Loss: 0.4658, LR: 0.000125
# Epoch [19/40], Time: 7.40s, Train Loss: 1.2446, Val Loss: 0.4570, LR: 0.000125
# Epoch [20/40], Time: 7.29s, Train Loss: 1.1714, Val Loss: 0.4472, LR: 0.000016
# Epoch [21/40], Time: 7.38s, Train Loss: 1.1906, Val Loss: 0.4563, LR: 0.000016
# Epoch [22/40], Time: 7.42s, Train Loss: 1.2033, Val Loss: 0.4479, LR: 0.000016
# Epoch [23/40], Time: 7.56s, Train Loss: 1.1867, Val Loss: 0.4320, LR: 0.000016
# Epoch [24/40], Time: 7.33s, Train Loss: 1.2281, Val Loss: 0.4425, LR: 0.000016
# Epoch [25/40], Time: 7.39s, Train Loss: 1.1701, Val Loss: 0.4407, LR: 0.000016
# Epoch [26/40], Time: 7.49s, Train Loss: 1.1219, Val Loss: 0.4387, LR: 0.000016
# Epoch [27/40], Time: 7.60s, Train Loss: 1.2246, Val Loss: 0.4371, LR: 0.000016
# Epoch [28/40], Time: 7.51s, Train Loss: 1.1598, Val Loss: 0.4281, LR: 0.000016
# Epoch [29/40], Time: 7.27s, Train Loss: 1.1751, Val Loss: 0.4181, LR: 0.000016
# Epoch [30/40], Time: 7.44s, Train Loss: 1.2035, Val Loss: 0.4353, LR: 0.000002
# Epoch [31/40], Time: 7.48s, Train Loss: 1.1523, Val Loss: 0.4236, LR: 0.000002
# Epoch [32/40], Time: 7.41s, Train Loss: 1.1257, Val Loss: 0.4420, LR: 0.000002
# Epoch [33/40], Time: 7.36s, Train Loss: 1.2118, Val Loss: 0.4426, LR: 0.000002
# Epoch [34/40], Time: 7.41s, Train Loss: 1.1231, Val Loss: 0.4378, LR: 0.000002
# Epoch [35/40], Time: 7.52s, Train Loss: 1.1352, Val Loss: 0.4407, LR: 0.000002
# Epoch [36/40], Time: 7.44s, Train Loss: 1.1534, Val Loss: 0.4390, LR: 0.000002
# Epoch [37/40], Time: 7.34s, Train Loss: 1.1738, Val Loss: 0.4331, LR: 0.000002
# Epoch [38/40], Time: 7.42s, Train Loss: 1.1805, Val Loss: 0.4296, LR: 0.000002
# Epoch [39/40], Time: 7.36s, Train Loss: 1.1230, Val Loss: 0.4234, LR: 0.000002
# Epoch [40/40], Time: 7.38s, Train Loss: 1.1960, Val Loss: 0.4151, LR: 0.000000

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
pretrained_encoder = model.encoder
for param in pretrained_encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  mnist_train_loader,
                                                                           val_loader = mnist_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-4)
# Out:
# Epoch [1/30], Time: 8.51s, Train Loss: 0.6854, Train Accuracy: 82.18%, Val Accuracy: 92.42%, LR: 0.000100
# Epoch [2/30], Time: 7.90s, Train Loss: 0.2944, Train Accuracy: 92.37%, Val Accuracy: 94.44%, LR: 0.000100
# Epoch [3/30], Time: 7.92s, Train Loss: 0.2146, Train Accuracy: 94.13%, Val Accuracy: 95.44%, LR: 0.000100
# Epoch [4/30], Time: 8.11s, Train Loss: 0.1756, Train Accuracy: 95.01%, Val Accuracy: 96.11%, LR: 0.000100
# Epoch [5/30], Time: 8.31s, Train Loss: 0.1487, Train Accuracy: 95.79%, Val Accuracy: 96.44%, LR: 0.000100
# Epoch [6/30], Time: 8.42s, Train Loss: 0.1289, Train Accuracy: 96.27%, Val Accuracy: 96.59%, LR: 0.000100
# Epoch [7/30], Time: 8.30s, Train Loss: 0.1169, Train Accuracy: 96.53%, Val Accuracy: 96.71%, LR: 0.000100
# Epoch [8/30], Time: 8.17s, Train Loss: 0.1052, Train Accuracy: 96.86%, Val Accuracy: 97.03%, LR: 0.000100
# Epoch [9/30], Time: 8.49s, Train Loss: 0.0983, Train Accuracy: 97.07%, Val Accuracy: 97.18%, LR: 0.000100
# Epoch [10/30], Time: 8.35s, Train Loss: 0.0891, Train Accuracy: 97.22%, Val Accuracy: 97.35%, LR: 0.000010
# Epoch [11/30], Time: 8.49s, Train Loss: 0.0817, Train Accuracy: 97.57%, Val Accuracy: 97.39%, LR: 0.000010
# Epoch [12/30], Time: 8.52s, Train Loss: 0.0802, Train Accuracy: 97.60%, Val Accuracy: 97.52%, LR: 0.000010
# Epoch [13/30], Time: 8.41s, Train Loss: 0.0790, Train Accuracy: 97.63%, Val Accuracy: 97.52%, LR: 0.000010
# Epoch [14/30], Time: 8.49s, Train Loss: 0.0763, Train Accuracy: 97.73%, Val Accuracy: 97.55%, LR: 0.000010
# Epoch [15/30], Time: 8.47s, Train Loss: 0.0789, Train Accuracy: 97.63%, Val Accuracy: 97.46%, LR: 0.000010
# Epoch [16/30], Time: 8.14s, Train Loss: 0.0779, Train Accuracy: 97.64%, Val Accuracy: 97.52%, LR: 0.000010
# Epoch [17/30], Time: 8.26s, Train Loss: 0.0763, Train Accuracy: 97.73%, Val Accuracy: 97.51%, LR: 0.000010
# Epoch [18/30], Time: 8.41s, Train Loss: 0.0749, Train Accuracy: 97.74%, Val Accuracy: 97.54%, LR: 0.000010
# Epoch [19/30], Time: 8.54s, Train Loss: 0.0730, Train Accuracy: 97.86%, Val Accuracy: 97.62%, LR: 0.000010
# Epoch [20/30], Time: 8.59s, Train Loss: 0.0732, Train Accuracy: 97.77%, Val Accuracy: 97.61%, LR: 0.000001
# Epoch [21/30], Time: 8.54s, Train Loss: 0.0741, Train Accuracy: 97.77%, Val Accuracy: 97.60%, LR: 0.000001
# Epoch [22/30], Time: 8.52s, Train Loss: 0.0731, Train Accuracy: 97.79%, Val Accuracy: 97.60%, LR: 0.000001
# Epoch [23/30], Time: 7.98s, Train Loss: 0.0706, Train Accuracy: 97.89%, Val Accuracy: 97.62%, LR: 0.000001
# Epoch [24/30], Time: 8.26s, Train Loss: 0.0729, Train Accuracy: 97.82%, Val Accuracy: 97.64%, LR: 0.000001
# Epoch [25/30], Time: 8.24s, Train Loss: 0.0722, Train Accuracy: 97.86%, Val Accuracy: 97.60%, LR: 0.000001
# Epoch [26/30], Time: 8.06s, Train Loss: 0.0723, Train Accuracy: 97.80%, Val Accuracy: 97.61%, LR: 0.000001
# Epoch [27/30], Time: 8.68s, Train Loss: 0.0710, Train Accuracy: 97.88%, Val Accuracy: 97.62%, LR: 0.000001
# Epoch [28/30], Time: 8.54s, Train Loss: 0.0723, Train Accuracy: 97.83%, Val Accuracy: 97.59%, LR: 0.000001
# Epoch [29/30], Time: 8.47s, Train Loss: 0.0730, Train Accuracy: 97.84%, Val Accuracy: 97.62%, LR: 0.000001
# Epoch [30/30], Time: 8.13s, Train Loss: 0.0719, Train Accuracy: 97.83%, Val Accuracy: 97.60%, LR: 0.000000

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=mnist_test_loader)
# Out:
# Test Accuracy: 97.97%

# %% [markdown]
# # Cifar10

# %% [markdown]
# # Preparing data

# %%
cifar10_path = "./cifar10_data"

train_transform = transforms.Compose([
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
])

c10_full_train_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,  
    train=True,       
    transform=train_transform,
    download=True     
)

c10_test_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,
    train=False,  
    transform=test_transform,
    download=True
)

print("CIFAR-10 dataset downloaded successfully!")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CIFAR-10 dataset downloaded successfully!

# %%
train_size = 40_000
val_size = 10_000
batch_size = 256

c10_train_dataset, c10_val_dataset = random_split(c10_full_train_dataset, [train_size, val_size])

# Check dataset sizes
print(f"Train size: {len(c10_train_dataset)}, Validation size: {len(c10_val_dataset)}, Test size: {len(c10_test_dataset)}")



# Create DataLoaders
c10_train_loader = DataLoader(c10_train_dataset, batch_size=batch_size, shuffle=True, num_workers = 1)
c10_val_loader = DataLoader(c10_val_dataset, batch_size=batch_size, shuffle=False, num_workers = 1)
c10_test_loader = DataLoader(c10_test_dataset, batch_size=batch_size, shuffle=False, num_workers = 1)

print("DataLoaders created successfully!")

# Get a batch of images and labels from the train_loader
images, labels = next(iter(c10_train_loader))
print(f"Batch shape: {images.shape}, Labels (first 5): {labels[:5]}")
# Out:
# Train size: 40000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!
# Batch shape: torch.Size([256, 3, 32, 32]), Labels (first 5): tensor([4, 5, 3, 6, 3])

# %% [markdown]
# # Experiment

# %%
model = Cifar10SimCLR(latent_dim=128,
                      dropout_prob=0.1,
                      temperature=0.1).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader = c10_train_loader,
                        val_loader = c10_val_loader,
                        num_epochs=40,
                        learning_rate=1e-3,
                        weight_decay= 1e-3)
# Out:
# Initializing weights ....
# Initializing weights DONE
# Epoch [1/40], Time: 10.85s, Train Loss: 2.6386, Val Loss: 0.4628, LR: 0.001000
# Epoch [2/40], Time: 10.48s, Train Loss: 1.4215, Val Loss: 0.2692, LR: 0.001000
# Epoch [3/40], Time: 10.39s, Train Loss: 1.2703, Val Loss: 0.2316, LR: 0.001000
# Epoch [4/40], Time: 10.57s, Train Loss: 1.0660, Val Loss: 0.2459, LR: 0.001000
# Epoch [5/40], Time: 10.60s, Train Loss: 1.0436, Val Loss: 0.1722, LR: 0.001000
# Epoch [6/40], Time: 10.84s, Train Loss: 0.9820, Val Loss: 0.1885, LR: 0.001000
# Epoch [7/40], Time: 10.98s, Train Loss: 0.9135, Val Loss: 0.1817, LR: 0.001000
# Epoch [8/40], Time: 10.84s, Train Loss: 0.8337, Val Loss: 0.1539, LR: 0.001000
# Epoch [9/40], Time: 10.49s, Train Loss: 0.8566, Val Loss: 0.1897, LR: 0.001000
# Epoch [10/40], Time: 10.75s, Train Loss: 0.7019, Val Loss: 0.1326, LR: 0.000125
# Epoch [11/40], Time: 10.65s, Train Loss: 0.7012, Val Loss: 0.1110, LR: 0.000125
# Epoch [12/40], Time: 10.68s, Train Loss: 0.6619, Val Loss: 0.1145, LR: 0.000125
# Epoch [13/40], Time: 11.16s, Train Loss: 0.6597, Val Loss: 0.1086, LR: 0.000125
# Epoch [14/40], Time: 10.65s, Train Loss: 0.6598, Val Loss: 0.1166, LR: 0.000125
# Epoch [15/40], Time: 10.91s, Train Loss: 0.6086, Val Loss: 0.1106, LR: 0.000125
# Epoch [16/40], Time: 10.82s, Train Loss: 0.6600, Val Loss: 0.1204, LR: 0.000125
# Epoch [17/40], Time: 10.37s, Train Loss: 0.5837, Val Loss: 0.1132, LR: 0.000125
# Epoch [18/40], Time: 10.80s, Train Loss: 0.6600, Val Loss: 0.1129, LR: 0.000125
# Epoch [19/40], Time: 10.70s, Train Loss: 0.5764, Val Loss: 0.1052, LR: 0.000125
# Epoch [20/40], Time: 10.72s, Train Loss: 0.6094, Val Loss: 0.1063, LR: 0.000016
# Epoch [21/40], Time: 10.78s, Train Loss: 0.6115, Val Loss: 0.1056, LR: 0.000016
# Epoch [22/40], Time: 10.38s, Train Loss: 0.5788, Val Loss: 0.1071, LR: 0.000016
# Epoch [23/40], Time: 10.39s, Train Loss: 0.5678, Val Loss: 0.1045, LR: 0.000016
# Epoch [24/40], Time: 10.98s, Train Loss: 0.5960, Val Loss: 0.1053, LR: 0.000016
# Epoch [25/40], Time: 10.80s, Train Loss: 0.5775, Val Loss: 0.1053, LR: 0.000016
# Epoch [26/40], Time: 10.89s, Train Loss: 0.5950, Val Loss: 0.1032, LR: 0.000016
# Epoch [27/40], Time: 11.02s, Train Loss: 0.5425, Val Loss: 0.1038, LR: 0.000016
# Epoch [28/40], Time: 10.69s, Train Loss: 0.6193, Val Loss: 0.1074, LR: 0.000016
# Epoch [29/40], Time: 10.77s, Train Loss: 0.5894, Val Loss: 0.1056, LR: 0.000016
# Epoch [30/40], Time: 11.17s, Train Loss: 0.5859, Val Loss: 0.1057, LR: 0.000002
# Epoch [31/40], Time: 10.61s, Train Loss: 0.6061, Val Loss: 0.1061, LR: 0.000002
# Epoch [32/40], Time: 10.82s, Train Loss: 0.5586, Val Loss: 0.1055, LR: 0.000002
# Epoch [33/40], Time: 10.85s, Train Loss: 0.5809, Val Loss: 0.1055, LR: 0.000002
# Epoch [34/40], Time: 10.55s, Train Loss: 0.5647, Val Loss: 0.1052, LR: 0.000002
# Epoch [35/40], Time: 10.88s, Train Loss: 0.5570, Val Loss: 0.1040, LR: 0.000002
# Epoch [36/40], Time: 10.65s, Train Loss: 0.5717, Val Loss: 0.1059, LR: 0.000002
# Epoch [37/40], Time: 10.83s, Train Loss: 0.6358, Val Loss: 0.1061, LR: 0.000002
# Epoch [38/40], Time: 10.92s, Train Loss: 0.5782, Val Loss: 0.1071, LR: 0.000002
# Epoch [39/40], Time: 10.20s, Train Loss: 0.5500, Val Loss: 0.1040, LR: 0.000002
# Epoch [40/40], Time: 10.34s, Train Loss: 0.5858, Val Loss: 0.1056, LR: 0.000000

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
for param in model.encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
pretrained_encoder = model.encoder
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  c10_train_loader,
                                                                           val_loader = c10_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-3)
# Out:
# Epoch [1/30], Time: 11.02s, Train Loss: 1.4410, Train Accuracy: 48.65%, Val Accuracy: 56.10%, LR: 0.001000
# Epoch [2/30], Time: 10.39s, Train Loss: 1.2816, Train Accuracy: 54.39%, Val Accuracy: 57.67%, LR: 0.001000
# Epoch [3/30], Time: 10.42s, Train Loss: 1.2265, Train Accuracy: 56.17%, Val Accuracy: 59.31%, LR: 0.001000
# Epoch [4/30], Time: 10.38s, Train Loss: 1.1929, Train Accuracy: 57.59%, Val Accuracy: 60.27%, LR: 0.001000
# Epoch [5/30], Time: 10.42s, Train Loss: 1.1671, Train Accuracy: 58.60%, Val Accuracy: 60.13%, LR: 0.001000
# Epoch [6/30], Time: 10.39s, Train Loss: 1.1468, Train Accuracy: 59.11%, Val Accuracy: 61.39%, LR: 0.001000
# Epoch [7/30], Time: 10.39s, Train Loss: 1.1259, Train Accuracy: 60.12%, Val Accuracy: 61.56%, LR: 0.001000
# Epoch [8/30], Time: 10.50s, Train Loss: 1.1067, Train Accuracy: 60.70%, Val Accuracy: 61.65%, LR: 0.001000
# Epoch [9/30], Time: 10.37s, Train Loss: 1.0890, Train Accuracy: 61.26%, Val Accuracy: 62.21%, LR: 0.001000
# Epoch [10/30], Time: 10.36s, Train Loss: 1.0776, Train Accuracy: 61.62%, Val Accuracy: 62.34%, LR: 0.000125
# Epoch [11/30], Time: 10.64s, Train Loss: 1.0124, Train Accuracy: 64.23%, Val Accuracy: 63.28%, LR: 0.000125
# Epoch [12/30], Time: 10.48s, Train Loss: 0.9866, Train Accuracy: 64.88%, Val Accuracy: 63.49%, LR: 0.000125
# Epoch [13/30], Time: 10.44s, Train Loss: 0.9780, Train Accuracy: 65.53%, Val Accuracy: 63.50%, LR: 0.000125
# Epoch [14/30], Time: 10.43s, Train Loss: 0.9652, Train Accuracy: 65.65%, Val Accuracy: 63.73%, LR: 0.000125
# Epoch [15/30], Time: 10.39s, Train Loss: 0.9568, Train Accuracy: 65.85%, Val Accuracy: 63.53%, LR: 0.000125
# Epoch [16/30], Time: 10.38s, Train Loss: 0.9489, Train Accuracy: 66.36%, Val Accuracy: 63.80%, LR: 0.000125
# Epoch [17/30], Time: 10.36s, Train Loss: 0.9422, Train Accuracy: 66.57%, Val Accuracy: 63.86%, LR: 0.000125
# Epoch [18/30], Time: 10.50s, Train Loss: 0.9341, Train Accuracy: 66.82%, Val Accuracy: 63.91%, LR: 0.000125
# Epoch [19/30], Time: 10.45s, Train Loss: 0.9296, Train Accuracy: 66.68%, Val Accuracy: 63.97%, LR: 0.000125
# Epoch [20/30], Time: 10.39s, Train Loss: 0.9267, Train Accuracy: 66.97%, Val Accuracy: 63.86%, LR: 0.000016
# Epoch [21/30], Time: 10.58s, Train Loss: 0.9121, Train Accuracy: 67.54%, Val Accuracy: 64.05%, LR: 0.000016
# Epoch [22/30], Time: 10.53s, Train Loss: 0.9086, Train Accuracy: 67.61%, Val Accuracy: 64.27%, LR: 0.000016
# Epoch [23/30], Time: 10.60s, Train Loss: 0.9139, Train Accuracy: 67.68%, Val Accuracy: 64.14%, LR: 0.000016
# Epoch [24/30], Time: 10.46s, Train Loss: 0.9083, Train Accuracy: 67.67%, Val Accuracy: 64.14%, LR: 0.000016
# Epoch [25/30], Time: 10.22s, Train Loss: 0.9135, Train Accuracy: 67.50%, Val Accuracy: 64.31%, LR: 0.000016
# Epoch [26/30], Time: 10.60s, Train Loss: 0.9088, Train Accuracy: 67.72%, Val Accuracy: 64.16%, LR: 0.000016
# Epoch [27/30], Time: 10.32s, Train Loss: 0.9044, Train Accuracy: 67.99%, Val Accuracy: 64.24%, LR: 0.000016
# Epoch [28/30], Time: 10.39s, Train Loss: 0.8998, Train Accuracy: 67.98%, Val Accuracy: 64.20%, LR: 0.000016
# Epoch [29/30], Time: 10.25s, Train Loss: 0.9008, Train Accuracy: 67.87%, Val Accuracy: 64.36%, LR: 0.000016
# Epoch [30/30], Time: 10.42s, Train Loss: 0.9052, Train Accuracy: 67.92%, Val Accuracy: 64.35%, LR: 0.000002

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=c10_test_loader)
# Out:
# Test Accuracy: 63.59%
