# %% [markdown]
# # Main For Part 3

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
from matplotlib import pyplot as plt
# Needed for training
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import random_split, DataLoader
from torch.utils.data.dataset import Subset
# Models
from models_part1 import FinalClassifier
from models_part3 import NTXentLoss,MnistSimCLR,Cifar10SimCLR
from models_testing import  plot_accuracies,plot_losses,test_classifier,test_classifyingAutoEncoder
from models_testing import create_model_folders,PretrainedModel,save_pretrained_model
# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
base_path = 'trained_models/part_3/'

# %% [markdown]
# # MNIST

# %% [markdown]
# # Preparing Data

# %%
mnist_path = "./mnist_data"

train_transform = transforms.Compose([
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.MNIST(
    root=mnist_path,  
    train=True,       
    transform=train_transform,  # Apply train transformations
    download=True     
)

test_dataset = torchvision.datasets.MNIST(
    root=mnist_path,
    train=False,  
    transform=test_transform,  # Apply test transformations
    download=True
)

print("MNIST dataset downloaded successfully!")
# Out:
# MNIST dataset downloaded successfully!

# %%
train_size = 50_000
val_size = 10_000
batch_size = 256


train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

print(f"Train size: {len(train_dataset)}, Validation size: {len(val_dataset)}, Test size: {len(test_dataset)}")

# Create DataLoaders
mnist_train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
mnist_val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
mnist_test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print("DataLoaders created successfully!")

# images, labels = next(iter(mnist_train_loader))
# print(f"Batch shape: {images.shape}, Labels: {labels[:5]}")
# Out:
# Train size: 50000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!

# %% [markdown]
# # Experiment

# %%
model = MnistSimCLR(latent_dim=128,dropout_prob=0.1,temperature = 0.1).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader= mnist_train_loader,
                       val_loader=mnist_val_loader,
                       num_epochs=40,
                       learning_rate=1e-3,
                       weight_decay= 1e-3)
# Out:
# Epoch [1/40], Time: 9.33s, Train Loss: 4.9513, Val Loss: 2.4756, LR: 0.001000
# Epoch [2/40], Time: 4.99s, Train Loss: 3.4035, Val Loss: 1.4264, LR: 0.001000
# Epoch [3/40], Time: 5.37s, Train Loss: 2.6592, Val Loss: 1.1327, LR: 0.001000
# Epoch [4/40], Time: 5.38s, Train Loss: 2.3859, Val Loss: 1.0901, LR: 0.001000
# Epoch [5/40], Time: 5.37s, Train Loss: 2.0416, Val Loss: 0.8142, LR: 0.001000
# Epoch [6/40], Time: 5.52s, Train Loss: 1.8733, Val Loss: 0.7934, LR: 0.001000
# Epoch [7/40], Time: 5.56s, Train Loss: 1.7202, Val Loss: 0.6309, LR: 0.001000
# Epoch [8/40], Time: 5.50s, Train Loss: 1.6457, Val Loss: 0.5940, LR: 0.001000
# Epoch [9/40], Time: 5.51s, Train Loss: 1.5972, Val Loss: 0.5330, LR: 0.001000
# Epoch [10/40], Time: 5.34s, Train Loss: 1.3904, Val Loss: 0.5134, LR: 0.001000
# Epoch [22/30], Time: 8.52s, Train Loss: 0.0656, Train Accuracy: 98.05%, Val Accuracy: 98.11%, LR: 0.000002
# Epoch [23/30], Time: 8.39s, Train Loss: 0.0645, Train Accuracy: 98.05%, Val Accuracy: 98.06%, LR: 0.000002
# Epoch [24/30], Time: 8.38s, Train Loss: 0.0641, Train Accuracy: 98.11%, Val Accuracy: 98.07%, LR: 0.000002
# Epoch [25/30], Time: 8.48s, Train Loss: 0.0657, Train Accuracy: 98.03%, Val Accuracy: 98.08%, LR: 0.000002
# Epoch [26/30], Time: 8.61s, Train Loss: 0.0648, Train Accuracy: 98.09%, Val Accuracy: 98.07%, LR: 0.000002
# Epoch [27/30], Time: 8.48s, Train Loss: 0.0652, Train Accuracy: 98.09%, Val Accuracy: 98.05%, LR: 0.000002
# Epoch [28/30], Time: 8.56s, Train Loss: 0.0644, Train Accuracy: 98.07%, Val Accuracy: 98.08%, LR: 0.000002
# Epoch [29/30], Time: 8.44s, Train Loss: 0.0653, Train Accuracy: 98.12%, Val Accuracy: 98.05%, LR: 0.000002
# Epoch [30/30], Time: 8.51s, Train Loss: 0.0646, Train Accuracy: 98.12%, Val Accuracy: 98.11%, LR: 0.000000

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=mnist_test_loader)
# Out:
# Test Accuracy: 98.15%

# %% [markdown]
# ## Saving model

# %%
save_pretrained_model(path = base_path + 'mnist.pth',
                      encoder = model.encoder,
                      classifier = classifier,
                      decoder = None)

# %% [markdown]
# # Cifar10

# %% [markdown]
# # Preparing data

# %%
cifar10_path = "./cifar10_data"

train_transform = transforms.Compose([
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
])

c10_full_train_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,  
    train=True,       
    transform=train_transform,
    download=True     
)

c10_test_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,
    train=False,  
    transform=test_transform,
    download=True
)

print("CIFAR-10 dataset downloaded successfully!")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CIFAR-10 dataset downloaded successfully!

# %%
train_size = 40_000
val_size = 10_000
batch_size = 256

c10_train_dataset, c10_val_dataset = random_split(c10_full_train_dataset, [train_size, val_size])

# Check dataset sizes
print(f"Train size: {len(c10_train_dataset)}, Validation size: {len(c10_val_dataset)}, Test size: {len(c10_test_dataset)}")



# Create DataLoaders
c10_train_loader = DataLoader(c10_train_dataset, batch_size=batch_size, shuffle=True)
c10_val_loader = DataLoader(c10_val_dataset, batch_size=batch_size, shuffle=False)
c10_test_loader = DataLoader(c10_test_dataset, batch_size=batch_size, shuffle=False)

print("DataLoaders created successfully!")

# Get a batch of images and labels from the train_loader
images, labels = next(iter(c10_train_loader))
print(f"Batch shape: {images.shape}, Labels (first 5): {labels[:5]}")
# Out:
# Train size: 40000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!
# Batch shape: torch.Size([256, 3, 32, 32]), Labels (first 5): tensor([7, 9, 5, 0, 3])

# %% [markdown]
# # Experiment

# %%
model = Cifar10SimCLR(latent_dim=128,
                      dropout_prob=0.1,
                      temperature=0.1).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader = c10_train_loader,
                        val_loader = c10_val_loader,
                        num_epochs=60,
                        learning_rate=1e-3,
                        weight_decay= 1e-3)
# Out:
# Initializing weights ....
# Initializing weights DONE
# Epoch [1/60], Time: 9.48s, Train Loss: 2.4276, Val Loss: 0.3750, LR: 0.001000
# Epoch [2/60], Time: 10.75s, Train Loss: 1.6120, Val Loss: 0.3886, LR: 0.001000
# Epoch [3/60], Time: 9.30s, Train Loss: 1.2928, Val Loss: 0.2267, LR: 0.001000
# Epoch [4/60], Time: 9.14s, Train Loss: 1.1997, Val Loss: 0.2091, LR: 0.001000
# Epoch [5/60], Time: 8.92s, Train Loss: 1.1611, Val Loss: 0.2206, LR: 0.001000
# Epoch [6/60], Time: 8.81s, Train Loss: 0.9757, Val Loss: 0.1643, LR: 0.001000
# Epoch [7/60], Time: 8.79s, Train Loss: 0.7994, Val Loss: 0.1970, LR: 0.001000
# Epoch [8/60], Time: 8.59s, Train Loss: 0.7821, Val Loss: 0.1364, LR: 0.001000
# Epoch [9/60], Time: 8.59s, Train Loss: 0.7083, Val Loss: 0.1423, LR: 0.001000
# Epoch [10/60], Time: 8.80s, Train Loss: 0.8389, Val Loss: 0.1772, LR: 0.001000
# Epoch [11/60], Time: 8.72s, Train Loss: 0.7638, Val Loss: 0.1743, LR: 0.001000
# Epoch [12/60], Time: 9.10s, Train Loss: 0.7298, Val Loss: 0.2181, LR: 0.001000
# Epoch [13/60], Time: 8.49s, Train Loss: 0.5633, Val Loss: 0.1169, LR: 0.001000
# Epoch [14/60], Time: 8.71s, Train Loss: 0.6178, Val Loss: 0.1766, LR: 0.001000
# Epoch [15/60], Time: 8.63s, Train Loss: 0.6265, Val Loss: 0.1425, LR: 0.001000
# Epoch [16/60], Time: 8.46s, Train Loss: 0.7155, Val Loss: 0.1236, LR: 0.001000
# Epoch [17/60], Time: 8.47s, Train Loss: 0.6299, Val Loss: 0.1261, LR: 0.001000
# Epoch [18/60], Time: 8.78s, Train Loss: 0.6122, Val Loss: 0.1247, LR: 0.001000
# Epoch [19/60], Time: 8.67s, Train Loss: 0.6099, Val Loss: 0.1154, LR: 0.001000
# Epoch [20/60], Time: 8.77s, Train Loss: 0.5713, Val Loss: 0.1013, LR: 0.001000
# Epoch [21/60], Time: 8.70s, Train Loss: 0.6401, Val Loss: 0.1696, LR: 0.001000
# Epoch [22/60], Time: 8.60s, Train Loss: 0.5875, Val Loss: 0.1345, LR: 0.001000
# Epoch [23/60], Time: 8.61s, Train Loss: 0.5587, Val Loss: 0.1283, LR: 0.001000
# Epoch [24/60], Time: 8.47s, Train Loss: 0.5582, Val Loss: 0.1038, LR: 0.001000
# Epoch [25/60], Time: 8.77s, Train Loss: 0.5735, Val Loss: 0.1058, LR: 0.001000
# Epoch [26/60], Time: 8.72s, Train Loss: 0.4941, Val Loss: 0.1259, LR: 0.000125
# Epoch [27/60], Time: 8.66s, Train Loss: 0.4879, Val Loss: 0.0876, LR: 0.000125
# Epoch [28/60], Time: 8.74s, Train Loss: 0.4350, Val Loss: 0.0872, LR: 0.000125
# Epoch [60/60], Time: 8.38s, Train Loss: 0.3881, Val Loss: 0.0812, LR: 0.000016

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
for param in model.encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
pretrained_encoder = model.encoder
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader = c10_train_loader,
                                                                           val_loader = c10_val_loader,
                                                                           num_epochs=40, 
                                                                           learning_rate=1e-3)
# Out:
# Epoch [1/40], Time: 10.70s, Train Loss: 1.3401, Train Accuracy: 52.47%, Val Accuracy: 59.13%, LR: 0.001000
# Epoch [2/40], Time: 10.49s, Train Loss: 1.1650, Train Accuracy: 58.67%, Val Accuracy: 61.07%, LR: 0.001000
# Epoch [3/40], Time: 10.50s, Train Loss: 1.1075, Train Accuracy: 60.78%, Val Accuracy: 62.31%, LR: 0.001000
# Epoch [4/40], Time: 10.55s, Train Loss: 1.0791, Train Accuracy: 61.66%, Val Accuracy: 63.13%, LR: 0.001000
# Epoch [5/40], Time: 10.43s, Train Loss: 1.0492, Train Accuracy: 62.83%, Val Accuracy: 63.41%, LR: 0.001000
# Epoch [6/40], Time: 10.52s, Train Loss: 1.0263, Train Accuracy: 63.34%, Val Accuracy: 63.83%, LR: 0.001000
# Epoch [7/40], Time: 10.55s, Train Loss: 1.0062, Train Accuracy: 64.19%, Val Accuracy: 63.68%, LR: 0.001000
# Epoch [8/40], Time: 10.47s, Train Loss: 0.9935, Train Accuracy: 64.95%, Val Accuracy: 64.12%, LR: 0.001000
# Epoch [9/40], Time: 10.43s, Train Loss: 0.9717, Train Accuracy: 65.55%, Val Accuracy: 64.53%, LR: 0.001000
# Epoch [10/40], Time: 10.42s, Train Loss: 0.9613, Train Accuracy: 65.88%, Val Accuracy: 64.47%, LR: 0.000125
# Epoch [11/40], Time: 10.50s, Train Loss: 0.8964, Train Accuracy: 68.17%, Val Accuracy: 65.47%, LR: 0.000125
# Epoch [12/40], Time: 10.33s, Train Loss: 0.8767, Train Accuracy: 68.88%, Val Accuracy: 65.81%, LR: 0.000125
# Epoch [13/40], Time: 10.41s, Train Loss: 0.8671, Train Accuracy: 69.06%, Val Accuracy: 65.82%, LR: 0.000125
# Epoch [14/40], Time: 10.42s, Train Loss: 0.8572, Train Accuracy: 69.61%, Val Accuracy: 66.10%, LR: 0.000125
# Epoch [15/40], Time: 10.43s, Train Loss: 0.8457, Train Accuracy: 70.07%, Val Accuracy: 66.29%, LR: 0.000125
# Epoch [16/40], Time: 10.47s, Train Loss: 0.8409, Train Accuracy: 69.95%, Val Accuracy: 66.25%, LR: 0.000125
# Epoch [17/40], Time: 10.64s, Train Loss: 0.8364, Train Accuracy: 70.20%, Val Accuracy: 66.55%, LR: 0.000125
# Epoch [18/40], Time: 10.40s, Train Loss: 0.8290, Train Accuracy: 70.55%, Val Accuracy: 66.50%, LR: 0.000125
# Epoch [19/40], Time: 10.44s, Train Loss: 0.8226, Train Accuracy: 70.92%, Val Accuracy: 66.42%, LR: 0.000125
