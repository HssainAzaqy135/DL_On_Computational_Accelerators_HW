# %% [markdown]
# # Main For Part 3

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
from matplotlib import pyplot as plt
# Needed for training
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import random_split, DataLoader
from torch.utils.data.dataset import Subset
# Models
from models_part1 import FinalClassifier
from models_part3 import NTXentLoss,MnistSimCLR,Cifar10SimCLR
from models_testing import  plot_accuracies,plot_losses,test_classifier,test_classifyingAutoEncoder
# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # MNIST

# %% [markdown]
# # Preparing Data

# %%
mnist_path = "./mnist_data"

transform = transforms.Compose([
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.5], std=[0.5])
])


train_dataset = torchvision.datasets.MNIST(
    root=mnist_path,  
    train=True,       
    transform=transform,  # Apply transformations here
    download=True     
)

test_dataset = torchvision.datasets.MNIST(
    root=mnist_path,
    train=False,  
    transform=transform,  # Apply same transformations for test data
    download=True
)

print("MNIST dataset downloaded successfully!")
# Out:
# MNIST dataset downloaded successfully!

# %%
train_size = 50_000
val_size = 10_000
batch_size = 256


train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

print(f"Train size: {len(train_dataset)}, Validation size: {len(val_dataset)}, Test size: {len(test_dataset)}")

# Create DataLoaders
mnist_train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers = 1)
mnist_val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers = 1)
mnist_test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers = 1)

print("DataLoaders created successfully!")

# images, labels = next(iter(mnist_train_loader))
# print(f"Batch shape: {images.shape}, Labels: {labels[:5]}")
# Out:
# Train size: 50000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!

# %% [markdown]
# # Experiment

# %%
model = MnistSimCLR(latent_dim=128,dropout_prob=0.1,temperature = 0.1).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader= mnist_train_loader,
                       val_loader=mnist_val_loader,
                       num_epochs=40,
                       learning_rate=1e-3,
                       weight_decay= 1e-3)
# Out:
# Epoch [1/40], Time: 12.99s, Train Loss: 5.0746, Val Loss: 2.6766, LR: 0.001000
# Epoch [2/40], Time: 7.81s, Train Loss: 3.7867, Val Loss: 1.8575, LR: 0.001000
# Epoch [3/40], Time: 7.63s, Train Loss: 2.9806, Val Loss: 1.4980, LR: 0.001000
# Epoch [4/40], Time: 8.08s, Train Loss: 2.5160, Val Loss: 1.1202, LR: 0.001000
# Epoch [5/40], Time: 8.93s, Train Loss: 2.2444, Val Loss: 0.9886, LR: 0.001000
# Epoch [6/40], Time: 7.88s, Train Loss: 2.1696, Val Loss: 0.9804, LR: 0.001000
# Epoch [7/40], Time: 7.76s, Train Loss: 1.8211, Val Loss: 0.8479, LR: 0.001000
# Epoch [8/40], Time: 7.68s, Train Loss: 1.6684, Val Loss: 0.7259, LR: 0.001000
# Epoch [9/40], Time: 7.58s, Train Loss: 1.6902, Val Loss: 0.6393, LR: 0.001000
# Epoch [10/40], Time: 7.84s, Train Loss: 1.5145, Val Loss: 0.5317, LR: 0.000100
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
pretrained_encoder = model.encoder
for param in pretrained_encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  mnist_train_loader,
                                                                           val_loader = mnist_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-4)
# Out:
# Epoch [1/30], Time: 8.77s, Train Loss: 0.7464, Train Accuracy: 79.88%, Val Accuracy: 90.45%, LR: 0.000100
# Epoch [2/30], Time: 8.90s, Train Loss: 0.3592, Train Accuracy: 90.73%, Val Accuracy: 93.28%, LR: 0.000100
# Epoch [3/30], Time: 8.19s, Train Loss: 0.2667, Train Accuracy: 92.90%, Val Accuracy: 94.30%, LR: 0.000100
# Epoch [4/30], Time: 8.19s, Train Loss: 0.2173, Train Accuracy: 94.00%, Val Accuracy: 95.26%, LR: 0.000100
# Epoch [5/30], Time: 8.11s, Train Loss: 0.1880, Train Accuracy: 94.67%, Val Accuracy: 94.94%, LR: 0.000100
# Epoch [6/30], Time: 8.56s, Train Loss: 0.1705, Train Accuracy: 95.11%, Val Accuracy: 95.17%, LR: 0.000100
# Epoch [7/30], Time: 8.88s, Train Loss: 0.1576, Train Accuracy: 95.43%, Val Accuracy: 95.99%, LR: 0.000100
# Epoch [8/30], Time: 8.63s, Train Loss: 0.1482, Train Accuracy: 95.62%, Val Accuracy: 95.77%, LR: 0.000100
# Epoch [9/30], Time: 8.34s, Train Loss: 0.1391, Train Accuracy: 95.81%, Val Accuracy: 95.54%, LR: 0.000100
# Epoch [10/30], Time: 8.32s, Train Loss: 0.1340, Train Accuracy: 95.90%, Val Accuracy: 96.22%, LR: 0.000010
# Epoch [11/30], Time: 8.18s, Train Loss: 0.1242, Train Accuracy: 96.29%, Val Accuracy: 96.82%, LR: 0.000010
# Epoch [12/30], Time: 8.38s, Train Loss: 0.1181, Train Accuracy: 96.48%, Val Accuracy: 96.95%, LR: 0.000010
# Epoch [13/30], Time: 8.57s, Train Loss: 0.1168, Train Accuracy: 96.51%, Val Accuracy: 96.96%, LR: 0.000010
# Epoch [14/30], Time: 8.65s, Train Loss: 0.1146, Train Accuracy: 96.63%, Val Accuracy: 97.02%, LR: 0.000010
# Epoch [15/30], Time: 8.39s, Train Loss: 0.1149, Train Accuracy: 96.47%, Val Accuracy: 96.96%, LR: 0.000010
# Epoch [16/30], Time: 8.16s, Train Loss: 0.1131, Train Accuracy: 96.50%, Val Accuracy: 96.99%, LR: 0.000010
# Epoch [17/30], Time: 8.15s, Train Loss: 0.1114, Train Accuracy: 96.64%, Val Accuracy: 97.02%, LR: 0.000010
# Epoch [18/30], Time: 8.18s, Train Loss: 0.1109, Train Accuracy: 96.65%, Val Accuracy: 97.06%, LR: 0.000010
# Epoch [19/30], Time: 8.76s, Train Loss: 0.1130, Train Accuracy: 96.56%, Val Accuracy: 97.05%, LR: 0.000010
# Epoch [20/30], Time: 8.60s, Train Loss: 0.1099, Train Accuracy: 96.63%, Val Accuracy: 97.05%, LR: 0.000001
# Epoch [21/30], Time: 8.65s, Train Loss: 0.1101, Train Accuracy: 96.69%, Val Accuracy: 97.05%, LR: 0.000001
# Epoch [22/30], Time: 8.38s, Train Loss: 0.1096, Train Accuracy: 96.69%, Val Accuracy: 97.10%, LR: 0.000001
# Epoch [23/30], Time: 8.28s, Train Loss: 0.1082, Train Accuracy: 96.70%, Val Accuracy: 97.05%, LR: 0.000001
# Epoch [24/30], Time: 8.51s, Train Loss: 0.1077, Train Accuracy: 96.78%, Val Accuracy: 97.06%, LR: 0.000001
# Epoch [25/30], Time: 8.67s, Train Loss: 0.1061, Train Accuracy: 96.83%, Val Accuracy: 97.03%, LR: 0.000001
# Epoch [26/30], Time: 8.61s, Train Loss: 0.1071, Train Accuracy: 96.82%, Val Accuracy: 97.09%, LR: 0.000001
# Epoch [27/30], Time: 8.54s, Train Loss: 0.1081, Train Accuracy: 96.73%, Val Accuracy: 97.04%, LR: 0.000001
# Epoch [28/30], Time: 8.60s, Train Loss: 0.1093, Train Accuracy: 96.69%, Val Accuracy: 97.11%, LR: 0.000001
# Epoch [29/30], Time: 8.62s, Train Loss: 0.1087, Train Accuracy: 96.74%, Val Accuracy: 97.09%, LR: 0.000001
# Epoch [30/30], Time: 8.52s, Train Loss: 0.1074, Train Accuracy: 96.75%, Val Accuracy: 97.05%, LR: 0.000000

# %%
plot_losses(train_losses)
plot_accuracies(train_accuracies, val_accuracies)

# %%
test_classifier(encoder=pretrained_encoder,
                classifier=classifier,
                test_loader=mnist_test_loader)
# Out:
# Test Accuracy: 97.62%

# %% [markdown]
# # Cifar10

# %% [markdown]
# # Preparing data

# %%
cifar10_path = "./cifar10_data"

transform = transforms.Compose([
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.5,0.5,0.5], std=[0.5,0.5,0.5]), #moved to model code for color jitter compatability
])

c10_full_train_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,  
    train=True,       
    transform=transform,
    download=True     
)

c10_test_dataset = torchvision.datasets.CIFAR10(
    root=cifar10_path,
    train=False,  
    transform=transform,
    download=True
)

print("CIFAR-10 dataset downloaded successfully!")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CIFAR-10 dataset downloaded successfully!

# %%
train_size = 40_000
val_size = 10_000
batch_size = 256

c10_train_dataset, c10_val_dataset = random_split(c10_full_train_dataset, [train_size, val_size])

# Check dataset sizes
print(f"Train size: {len(c10_train_dataset)}, Validation size: {len(c10_val_dataset)}, Test size: {len(c10_test_dataset)}")



# Create DataLoaders
c10_train_loader = DataLoader(c10_train_dataset, batch_size=batch_size, shuffle=True, num_workers = 1)
c10_val_loader = DataLoader(c10_val_dataset, batch_size=batch_size, shuffle=False, num_workers = 1)
c10_test_loader = DataLoader(c10_test_dataset, batch_size=batch_size, shuffle=False, num_workers = 1)

print("DataLoaders created successfully!")

# Get a batch of images and labels from the train_loader
images, labels = next(iter(c10_train_loader))
print(f"Batch shape: {images.shape}, Labels (first 5): {labels[:5]}")
# Out:
# Train size: 40000, Validation size: 10000, Test size: 10000
# DataLoaders created successfully!
# Batch shape: torch.Size([256, 3, 32, 32]), Labels (first 5): tensor([2, 1, 0, 4, 4])

# %% [markdown]
# # Experiment

# %%
model = Cifar10SimCLR(latent_dim=128,
                      dropout_prob=0.1,
                      temperature=0.1).to(device)
train_losses,val_losses = model.train_autoencoder(train_loader = c10_train_loader,
                        val_loader = c10_val_loader,
                        num_epochs=40,
                        learning_rate=1e-3,
                        weight_decay= 1e-3)
# Out:
# Initializing weights ....
# Initializing weights DONE
# Epoch [1/40], Time: 12.50s, Train Loss: 3.2161, Val Loss: 0.6815, LR: 0.001000
# Epoch [2/40], Time: 12.03s, Train Loss: 2.1197, Val Loss: 0.4176, LR: 0.001000
# Epoch [3/40], Time: 12.14s, Train Loss: 1.9225, Val Loss: 0.3550, LR: 0.001000
# Epoch [4/40], Time: 12.28s, Train Loss: 1.6115, Val Loss: 0.3070, LR: 0.001000
# Epoch [5/40], Time: 12.20s, Train Loss: 1.3892, Val Loss: 0.2883, LR: 0.001000
# Epoch [6/40], Time: 12.43s, Train Loss: 1.4176, Val Loss: 0.2115, LR: 0.001000
# Epoch [7/40], Time: 12.17s, Train Loss: 1.3014, Val Loss: 0.2196, LR: 0.001000
# Epoch [8/40], Time: 12.64s, Train Loss: 1.2167, Val Loss: 0.1751, LR: 0.001000
# Epoch [9/40], Time: 11.85s, Train Loss: 1.0107, Val Loss: 0.1650, LR: 0.001000
# Epoch [10/40], Time: 11.91s, Train Loss: 1.0293, Val Loss: 0.1717, LR: 0.000100
# Epoch [11/40], Time: 12.02s, Train Loss: 0.9749, Val Loss: 0.1435, LR: 0.000100
# Epoch [12/40], Time: 12.14s, Train Loss: 1.0161, Val Loss: 0.1504, LR: 0.000100
# Epoch [13/40], Time: 11.75s, Train Loss: 0.9620, Val Loss: 0.1456, LR: 0.000100
# Epoch [14/40], Time: 12.10s, Train Loss: 0.8801, Val Loss: 0.1392, LR: 0.000100
# Epoch [15/40], Time: 12.45s, Train Loss: 0.9814, Val Loss: 0.1415, LR: 0.000100
# Epoch [16/40], Time: 12.19s, Train Loss: 0.9167, Val Loss: 0.1403, LR: 0.000100
# Epoch [17/40], Time: 12.56s, Train Loss: 0.8323, Val Loss: 0.1353, LR: 0.000100
# Epoch [18/40], Time: 11.91s, Train Loss: 0.8753, Val Loss: 0.1357, LR: 0.000100
# Epoch [19/40], Time: 12.36s, Train Loss: 0.8814, Val Loss: 0.1340, LR: 0.000100
# Epoch [20/40], Time: 12.29s, Train Loss: 0.8631, Val Loss: 0.1353, LR: 0.000010
# Epoch [21/40], Time: 12.13s, Train Loss: 0.8041, Val Loss: 0.1335, LR: 0.000010
# Epoch [22/40], Time: 12.58s, Train Loss: 0.8557, Val Loss: 0.1358, LR: 0.000010
# Epoch [23/40], Time: 12.15s, Train Loss: 0.7970, Val Loss: 0.1324, LR: 0.000010
# Epoch [24/40], Time: 12.18s, Train Loss: 0.8214, Val Loss: 0.1339, LR: 0.000010
# Epoch [25/40], Time: 11.91s, Train Loss: 0.7776, Val Loss: 0.1312, LR: 0.000010
# Epoch [26/40], Time: 12.20s, Train Loss: 0.8514, Val Loss: 0.1326, LR: 0.000010
# Epoch [27/40], Time: 12.40s, Train Loss: 0.8688, Val Loss: 0.1316, LR: 0.000010
# Epoch [28/40], Time: 12.33s, Train Loss: 0.8292, Val Loss: 0.1321, LR: 0.000010
# Epoch [29/40], Time: 12.36s, Train Loss: 0.7952, Val Loss: 0.1334, LR: 0.000010
# Epoch [30/40], Time: 12.33s, Train Loss: 0.8799, Val Loss: 0.1369, LR: 0.000001
# Epoch [31/40], Time: 12.09s, Train Loss: 0.7931, Val Loss: 0.1295, LR: 0.000001
# Epoch [32/40], Time: 12.09s, Train Loss: 0.7840, Val Loss: 0.1316, LR: 0.000001
# Epoch [33/40], Time: 12.11s, Train Loss: 0.8612, Val Loss: 0.1336, LR: 0.000001
# Epoch [34/40], Time: 12.21s, Train Loss: 0.7529, Val Loss: 0.1306, LR: 0.000001
# Epoch [35/40], Time: 12.34s, Train Loss: 0.7602, Val Loss: 0.1306, LR: 0.000001
# Epoch [36/40], Time: 12.02s, Train Loss: 0.8413, Val Loss: 0.1326, LR: 0.000001
# Epoch [37/40], Time: 11.82s, Train Loss: 0.8127, Val Loss: 0.1306, LR: 0.000001
# Epoch [38/40], Time: 11.87s, Train Loss: 0.8087, Val Loss: 0.1280, LR: 0.000001
# Epoch [39/40], Time: 12.40s, Train Loss: 0.7684, Val Loss: 0.1294, LR: 0.000001
# Epoch [40/40], Time: 12.11s, Train Loss: 0.8312, Val Loss: 0.1335, LR: 0.000000

# %%
plot_losses(train_losses = train_losses, val_losses = val_losses)

# %%
for param in model.encoder.parameters():
    param.requires_grad = False  # Ensure encoder is frozen
pretrained_encoder = model.encoder
classifier = FinalClassifier(latent_dim=128)
train_losses, train_accuracies, val_accuracies = classifier.fit_classifier(encoder = pretrained_encoder,
                                                                           train_loader =  c10_train_loader,
                                                                           val_loader = c10_val_loader,
                                                                           num_epochs=30, 
                                                                           learning_rate=1e-3)
# Out:
# Epoch [1/30], Time: 10.74s, Train Loss: 1.4441, Train Accuracy: 48.86%, Val Accuracy: 54.88%, LR: 0.001000
# Epoch [2/30], Time: 10.59s, Train Loss: 1.3032, Train Accuracy: 53.87%, Val Accuracy: 56.64%, LR: 0.001000
# Epoch [3/30], Time: 10.71s, Train Loss: 1.2464, Train Accuracy: 55.80%, Val Accuracy: 57.95%, LR: 0.001000
# Epoch [4/30], Time: 10.60s, Train Loss: 1.2108, Train Accuracy: 56.80%, Val Accuracy: 58.91%, LR: 0.001000
# Epoch [5/30], Time: 10.48s, Train Loss: 1.1838, Train Accuracy: 58.29%, Val Accuracy: 59.26%, LR: 0.001000
# Epoch [6/30], Time: 10.61s, Train Loss: 1.1634, Train Accuracy: 59.02%, Val Accuracy: 60.03%, LR: 0.001000
# Epoch [7/30], Time: 10.64s, Train Loss: 1.1411, Train Accuracy: 59.63%, Val Accuracy: 60.57%, LR: 0.001000
# Epoch [8/30], Time: 10.37s, Train Loss: 1.1292, Train Accuracy: 60.05%, Val Accuracy: 60.27%, LR: 0.001000
# Epoch [9/30], Time: 10.50s, Train Loss: 1.1085, Train Accuracy: 60.62%, Val Accuracy: 60.95%, LR: 0.001000
